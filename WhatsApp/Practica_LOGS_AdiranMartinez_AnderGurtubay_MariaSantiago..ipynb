# %%
import io
import sys

path = "drive/MyDrive/Datos_no_estructurados/WHATTSAPP/"

    
def replace_bad_character(line):
    return line.strip().replace(u"\u202a", "").replace(u"\u200e", "").replace(u"\u202c", "").replace(u"\xa0", " ")

try: 
    filepath = raw_input("Please input the chat filepath:")
except NameError:
    filepath = input("Please input chat filepath:")

try:
    with io.open(filepath, "r", encoding="utf-8") as file:
        content = [replace_bad_character(l) for l in file.readlines()]
    
except IOError as e:
    print("File \"" + filepath + "\" not found. Please recheck your file location")
    sys.exit()

common_words = []
cw_filepath = ""

cw_option = "Please select common word file or leave it blank to escape: \n\
    1: Indonesian (id_cw.py)\n\
    2: English (en_cw.py)\n\
    3: Spanish (es_cw.py)\n\
    4: German (de_cw.py)\n\
    5: Custom file\n\
    6: Skip common word\n"
try: 
    cw = raw_input(cw_option)
except NameError:
    cw = input(cw_option)
    
if cw == "1":
    cw_filepath = path+"id_cw"
elif cw == "2":
    cw_filepath = path+"en_cw"
elif cw == "3":
    cw_filepath = path+"es_cw"
elif cw == "4":
    cw_filepath = path+"de_cw"
elif cw == "5":
    """
    Prompt user to input the file path
    """
    try: 
        cw_filepath = raw_input("Please input your common word filepath")
    except NameError:
        cw_filepath = input("Please input your common word filepath")
else:
    print("You skipped common word.")

try:
    with open(f"{cw_filepath}.txt", "r") as fout:
      common_words = fout.read()

except:
    print("Error getting common word file location")
    sys.exit()

print(common_words)

try: 
    verbose = raw_input("You wanna print the verbose mode? y/[N]: ") == "y" or False
except NameError:
    verbose = input("You wanna print the verbose mode? y/[N]: ") == "y" or False
# ./drive/MyDrive/Datos_no_estructurados/WHATTSAPP/Chat_GirlsClub.txt
# Out:
# Please input chat filepath:./drive/MyDrive/Datos_no_estructurados/WHATTSAPP/Padel.txt
# Please select common word file or leave it blank to escape:
#     1: Indonesian (id_cw.py)
#     2: English (en_cw.py)
#     3: Spanish (es_cw.py)
#     4: German (de_cw.py)
#     5: Custom file
#     6: Skip common word
# 3
# common_words = [
# "de",
# "la",
# "las",
# "estoy",
# "que",
# "el",
# "multimedia",
# "omitido",
# "y",
# "gif",
# "imagen",
# "omitida",
# "sticker",
# "n",
# "a",
# "los",
# "del",
# "se",
# "por",
# "un",
# "con",
# "para",
# "no",
# "una",
# "su",
# "al",
# "lo",
# "como",
# "más",
# "o",
# "este",
# "pero",
# "sus",
# "esta",
# "si",
# "ha",
# "me",
# "ya",
# "le",
# "son",
# "sobre",
# "entre",
# "ser",
# "fue",
# "sin",
# "todo",
# "también",
# "desde",
# "cuando",
# "muy",
# "años",
# "está",
# "todos",
# "hay",
# "tiene",
# "nos",
# "porque",
# "dos",
# "hasta",
# "donde",
# "parte",
# "así",
# "han",
# "puede",
# "mi",
# "año",
# "cada",
# "uno",
# "vez",
# "bien",
# "hace",
# "otros",
# "eso",
# "además",
# "mismo",
# "ese",
# "hacer",
# "yo",
# "durante",
# "te",
# "día",
# "tanto",
# "esto",
# "forma",
# "estos",
# "sólo",
# "personas",
# "ni",
# "otro",
# "ahora",
# "hoy",
# "era",
# "están
# "les",
# "mejor",
# "qué",
# "quien",
# "cual",
# "esa",
# "general",
# "siempre",
# "menos",
# "contra",
# "más",
# "mayor",
# "otra",
# "mucho",
# "dijo",
# "tienen",
# "sido",
# "ante",
# "según",
# "tener",
# "primera",
# "sea",
# "debe",
# "después",
# "aunque",
# "solo",
# "ellos",
# "todas",
# "nuestro",
# "otras",
# "antes",
# "luego",
# "estas",
# "tu",
# "algo",
# "había",
# "primer",
# "nada",
# "hecho",
# "poco",
# "bro",
# "pueden",
# "va",
# "tan",
# "toda",
# "mientras",
# "pues",
# "muchos",
# "él",
# "tan",
# "cosas",
# "cualquier",
# "sí",
# "unos",
# "hacia",
# "misma",
# "estar",
# "ello",
# "gracias",
# "quienes",
# "embargo",
# "creo",
# "nosotros",
# "final",
# "muchas",
# "tras",
# "casi",
# "dice",
# "veces",
# "punto",
# "partir",
# "haber",
# "aún",
# "aqui",
# "aquí",
# "grandes",
# "nunca",
# "nuestros"]
#
# You wanna print the verbose mode? y/[N]: y

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading https://files.pythonhosted.org/packages/24/fa/b3368f41b95a286f8d300e323449ab4e86b85334c2e0b477e94422b8ed0f/emoji-1.2.0-py3-none-any.whl (131kB)
#      |████████████████████████████████| 133kB 13.8MB/s
# Installing collected packages: emoji
# Successfully installed emoji-1.2.0

# %%
import re
import errno
import pandas as pd
import emoji
from collections import Counter
from dateutil import parser
import operator
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
# %matplotlib inline


class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
"""
Global vars
"""
chat_of_members = {}
member_chat = {"member": [], "chat_count": []}
member_chat_words = {}
member_words = {}
words_list = []
attachments = {}
refered_web = {"domain": [], "d_count": []}
popular_words = {}
chat_words = ""
emojis = {"emj_char": [], "char_count": []}
heat_map = {
    "day": [], 
    "hour": [], 
    "chat_count": []
}
deleted_message = 0
pure_chat = ""
total_chat = 0

"""
Starting line mean a line that started with date time.
Because there are multiline chat. I called it following line.
A starting line must be classified before it's data being extracted.
"""
def is_starting_line(line):
    pattern = r"""
        (\[?)       #Zero or one open square bracket '['
        (((\d{1,2})   #1 to 2 digit date
        (/|-)       #'/' or '-' separator
        (\d{1,2})   #1 to 2 digit month
        (/|-)       #'/' or '-' separator
        (\d{2,4}))   #2 to 4 digit of year
        (,?\s)      #Zero or one comma ',' and ingle space
        ((\d{1,2})  #1 to 2 digit of hour
        (:|\.)      #Colon ':' or dot '.' separator
        (\d{2})     #2 digit of minute
        (\.|:)?     #Zero or one of dot '.' or colon ':'
        (\d{2})?    #Zero or one of 2 digits of second
        (\s[AP]M)?))  #Zero or one of ('space', 'A' or 'P', and 'M'
        (\]?\s-?\s?\s?)#Zero or one close square bracket ']', Zero or one (space and '-'), zero or one space
        (.+)        #One or more character of chat member phone number or contact name
    """
    
    return re.match(re.compile(pattern, re.VERBOSE), line)

"""
"Is Chat" means the body of a line is not an event.
May contains attachment
"""
def is_chat(body):
    pattern = r"""
            ([^:]+)#Chat member
            (:)   #Colon separator
            (.+)  #One or more charachter of message content
    """
    
    return re.match(re.compile(pattern, re.VERBOSE), body)

"""
Classify attachment
Note: in Android, there is no proper description wether it's a image, 
      video, audio, gif, or sticker.
"""
def contains_attachment(body):
    pattern_attachment = [
        ".*<Media omitted>$", #English version of android attachment
        ".*<Media tidak disertakan>$", #Indonesia version of android attachment
        ".*Pesan tidak didukung$", #Some device not recognize sticker attachment
        ".+\.vcf \(file\sterlampir\)$", #Indonesian version of android contact card,
        ".+\.vcf \(file\sattached\)$", #Indonesian version of android contact card,
        ".*image omitted$",
        ".*video omitted$",
        ".*document omitted$",
        ".*Contact card omitted$",
        ".*audio omitted$",
        ".*GIF omitted$",
        ".*sticker omitted$"
    ]
    
    for p in pattern_attachment:
        match = re.match(p, body)
        if match:
            return body
    return None

"""
Event means logs of chat activity e.g member left, member added, removed, etc.
This kind of line can not count as a chat
"""
def is_event(body):
    pattern_event = [
        "Messages to this group are now secured with end-to-end encryption\.$",
        ".+\screated this group$",
        ".+\skeluar$",
        ".+\sleft$",
        ".+\stelah bergabung menggunakan tautan undangan grup ini$",
        ".+\smenambahkan\s.+",
        ".+\sadded\s.+",
        ".+\sremoved\s.+",
        ".*You joined using this group's invite links$",
        ".+'s security code changed\.$",
        ".*telah mengganti nomor teleponnya ke nomor baru. Ketuk untuk mengirim pesan atau menambahkan nomor baru\.$",
        ".*changed their phone number to a new number. Tap to message or add the new number\.$"
    ]
    
    for p in pattern_event:
        match = re.match(p, body)
        if match:
            return match
    return None
"""
Deleted message
"""
def is_deleted(body):
    p = [
        ".*This message was deleted\.$",
        ".*Pesan ini telah dihapus$"
    ]
    
    for p in p:
        match = re.match(p, body)
        if match:
            return body
    return None

"""
EXTRACT TIMESTAMP
"""
def extract_timestamp(time_string):
    return parser.parse(time_string)

"""
Check if chat contais a url
"""
def extract_url(body):
    pattern = "https?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+"
    
    return re.findall(pattern, body)

def get_domain(str):
    domain = str.replace("http://", '')
    domain = domain.replace("https://", '')
    domain = domain.split("/")
    return domain[0]

"""
EMOJI
"""
def extract_emojis(string):
    emj = re.findall(r'\d+(.*?)(?:\u263a|\U0001f645)', string)

    if len(emj) > 0:
        increment_emoji_count(emj)
    
    return emj

"""
Count top words
"""
def get_words(msg, user):
    
    #remove non alpha content
    regex = re.sub(r"[^a-z\s]+", "", msg.lower())
    regex = re.sub(r'[^\x00-\x7f]',r'', regex)
    words = regex.split(" ")
    
    for x in words:
        if x:
            rank_word(x, user)
            
    return words
        
def rank_word(word, user):
    
    if not word in common_words:
        popular_words[word] = popular_words.get(word, 0) + 1
        global chat_words
        chat_words += " {0}".format(word)
        
        increment_member_words(user, word)
        
    return word
    
"""
Counting function
"""

"""
Rank the 'Most Active user'
"""        
def increment_chat_count(member):
    member_chat["member"].append(member)
    member_chat["chat_count"].append(1)
    global total_chat
    total_chat += 1
    
    return member

def increment_member_words(member, word):
    
    if member != None:
        words_list = []
        if member not in member_words.keys():
            words_list.append(word)
            member_words[member] = words_list
        else:
            words_list = member_words[member]
            words_list.append(word)
            member_words[member] = words_list
        
    return member
 
def increment_attachment_count(message):
    
    if "image omitted" in message:
        attachments["image"] = attachments.get("image", 0) +1
        return
        
    if "video omitted" in message:
        attachments["video"] = attachments.get("video", 0) +1
        return
    
    if "audio omitted" in message:
        attachments["audio"] = attachments.get("audio", 0) +1
        return
    
    if "document omitted" in message:
        attachments["document"] = attachments.get("document", 0) +1
        return
    
    if "Contact card omitted" in message or ".vcf" in message:
        attachments["contact"] = attachments.get("contact", 0) +1
        return
    
    if "GIF omitted" in message:
        attachments["gif"] = attachments.get("gif", 0) +1
        return
    
    if "sticker omitted" in message:
        attachments["sticker"] = attachments.get("sticker", 0) +1
        return
    
    ##Unknown attachment
    attachments["unknown"] = attachments.get("unknown", 0) +1

    

def increment_link_count(urls):
    for url in urls:
        increment_domain_count(get_domain(url))
                    
    return len(urls)
    
def increment_domain_count(domain):
    refered_web["domain"].append(domain)
    refered_web["d_count"].append(1)

def increment_emoji_count(char_list):
    groups = Counter(char_list)
    for c in groups.items():
        emojis["emj_char"].append(c[0])
        emojis["char_count"].append(c[1])
        
def increment_heatmap(dt):
    heat_map["day"].append(dt.strftime("%A"))
    heat_map["hour"].append(dt.strftime("%H"))
    heat_map["chat_count"].append(1)

def increment_deleted():
    global deleted_message
    deleted_message += 1
"""
Self explained
"""
def parse_line(line, verbose):
    prefix = ""
    is_starting = is_starting_line(line)
    
    if is_starting:
        #Check wether the starting line is a chat or an event
        body = is_starting.group(18)
        chat = is_chat(body)
        dt = extract_timestamp(is_starting.group(2).replace(".", ":"))
        increment_heatmap(dt)
        
        if chat:
            has_attachment = contains_attachment(chat.group(3))
            increment_chat_count(chat.group(1)) #chat.group(1) es el member
            message_body = chat.group(3)
            user = chat.group(1)
            
            
            if has_attachment:
                prefix = "@@@" 
                increment_attachment_count(has_attachment)
                
                if verbose: print(bcolors.OKBLUE + bcolors.HEADER + prefix + line)
                
            else:
                if is_deleted(message_body):
                    increment_deleted()
                else:
                    prefix = "+++"
                    
                    #URL & Domain
                    urls = extract_url(message_body)
                    if urls:
                        increment_link_count(urls)

                    #Emoji
                    emjs = extract_emojis(message_body)
                    
                    #Word Count & Wordcloud
                    get_words(message_body, user)
                
                    if verbose: print(bcolors.OKGREEN + bcolors.HEADER + prefix + line)
                
        elif is_event(body):
            prefix = "***"
                
            if verbose: print(bcolors.WARNING + prefix + line)
        
    else:
        prefix = "|||"
        
        #URL & Domain
        urls = extract_url(line)
        if urls:
            increment_link_count(urls)
        
        #Emoji    
        emjs = extract_emojis(line)
        
        #Word Count & Wordcloud
        get_words(line, None)

        if verbose: print(bcolors.FAIL + prefix + line)

print("Extracting data. Please wait....")

for line in content:
    parse_line(line, verbose)
    
print("Done. You can run next cell.")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# +++17/3/20 19:16 - Nano: Yo espero a Dave
# +++17/3/20 19:17 - Nano: Cuanto te queda?
# +++17/3/20 19:19 - Calleja: Estamos en privadas
# +++17/3/20 19:19 - Calleja: Merete
# +++17/3/20 19:20 - Ander: Yo echando me digáis estoy
# +++17/3/20 19:24 - Ander: Cuando*
# +++17/3/20 19:29 - Nano: Voy
# +++17/3/20 19:29 - Nano: Me meto
# +++17/3/20 19:58 - Deivid: Estoy de gym broders
# +++17/3/20 19:58 - Deivid: Acabo en breves
# +++17/3/20 19:58 - Deivid: No se si habra acabado de descargarse
# +++17/3/20 20:39 - Ander: Acabamos de dejarlo
# +++17/3/20 20:43 - Ander: Chavales miraos dos juegos que son de pc
# +++17/3/20 20:43 - Ander: El dont starve together y el portal 2 a ver si os rentan
# +++17/3/20 20:50 - Calleja: Hay que descargar?
# +++17/3/20 21:10 - Nano: Eh
# +++17/3/20 21:10 - Nano: Ojo un rocket league
# +++17/3/20 21:10 - Nano: OJO
# +++17/3/20 21:10 - Nano: descargo eso?
# +++17/3/20 21:10 - Deivid: A mi me renta
# +++17/3/20 21:12 - Calleja: Yo hoyo
# +++17/3/20 21:12 - Calleja: Salvo que querais un pinturillo
# +++17/3/20 21:13 - Deivid: Que es un pinturillo?
# +++17/3/20 21:14 - Nano: Yo esta noche no sé, pero cerramos un rocket league mañana
# +++17/3/20 21:15 - Deivid: Nano tu que eres periodista
# +++17/3/20 21:15 - Deivid: Q es un pinturillo
# +++17/3/20 21:15 - Deivid: ?
# +++17/3/20 21:17 - Nano: Es mofa
# +++17/3/20 21:17 - Nano: Tú dibujas algo
# +++17/3/20 21:17 - Nano: Y el otro tiene que adivinirlo
# +++17/3/20 21:22 - Deivid: Pero pq no puede rocket?
# +++17/3/20 21:23 - Nano: 🤷‍♂
# +++17/3/20 21:27 - Deivid: Calleja habla
# +++17/3/20 21:27 - Deivid: Da la car
# +++17/3/20 21:53 - Calleja: Donde?
# +++17/3/20 21:54 - Calleja: No tengo el rocket
# +++17/3/20 21:54 - Deivid: Ordenador?
# +++17/3/20 21:54 - Deivid: Yo tp lo tengo
# +++17/3/20 21:59 - Calleja: No puedo ibstalar nada
# +++17/3/20 21:59 - Calleja: Unos clubes
# +++17/3/20 21:59 - Calleja: ?
# +++17/3/20 22:00 - Calleja: Coño que no puedes
# +++17/3/20 22:00 - Deivid: Pero no entiend, tu ordenador?
# +++17/3/20 22:00 - Calleja: Empresa
# +++17/3/20 22:21 - Ander: Puedes rocket league en la play
# +++17/3/20 22:21 - Ander: esta a 50%
# +++17/3/20 22:21 - Ander: que lo he visto antes
# +++17/3/20 22:21 - Ander: cuesta 9 euros
# +++17/3/20 22:22 - Calleja: Pues lo intento para mañana
# +++17/3/20 22:22 - Ander: Y es juegazo
# +++17/3/20 22:22 - Calleja: Que va a jugar mi hermano
# +++17/3/20 23:40 - Deivid: Apex legand
# +++17/3/20 23:40 - Deivid: Shooter gratis
# +++17/3/20 23:40 - Deivid: Muy buena pinta
# +++17/3/20 23:40 - Deivid: Paladins es un juego que jugaba yo tipo lol pero más rápido y bastante divertido
# +++17/3/20 23:41 - Deivid: Propuestas de mi hermano mayor
# +++17/3/20 23:41 - Deivid: Pero tu no tienes ordenador calle?
# +++17/3/20 23:42 - Deivid: Q no sea de empresa
# +++17/3/20 23:42 - Deivid: Tienes que tener
# +++18/3/20 11:41 - Ander: Me compro el rocket broders
# +++18/3/20 11:42 - Ander: me renta mazo por 10 pavos
# +++18/3/20 11:53 - Nano: Ou mama
# +++18/3/20 11:54 - Nano: Me lo pillo y le damos esta tarde
# +++18/3/20 11:54 - Nano: Rollo 7
# +++18/3/20 11:54 - Nano: Dave puede jugar desde el ordenav
# +++18/3/20 11:59 - Deivid: Va yo lo pillo tb
# +++18/3/20 12:01 - Deivid: Lo malo es que yo de 7 a 8 estoy de gym
# +++18/3/20 12:02 - Deivid: Es a la hora que hacemos deporte en mi casa
# +++18/3/20 12:02 - Ander: Pues tu yo yo nano
# +++18/3/20 12:02 - Ander: mano a mano
# +++18/3/20 12:10 - Nano: De locos
# +++18/3/20 12:10 - Nano: Pero yo le doy un par de horitas, te metes luego dave
# +++18/3/20 12:11 - Ander: Perfe💪🏻
# +++18/3/20 12:29 - Deivid: Yes sir😉
# +++18/3/20 12:33 - Deivid: Cuesta 20 pavitos tu
# +++18/3/20 12:33 - Deivid: Me duel
# +++18/3/20 12:33 - Deivid: Duele
# +++18/3/20 12:34 - Deivid: Voy a buscarlo pirata
# +++18/3/20 12:35 - Nano: Esque en play está rebajado
# +++18/3/20 12:37 - Deivid: Que hijosdeputa
# +++18/3/20 12:39 - Ander: Sip
# +++18/3/20 12:39 - Ander: 10 euros cuesta
# +++18/3/20 12:39 - Ander: estas que no lo pillo
# +++18/3/20 13:08 - Calleja: <Multimedia omitido>
# +++18/3/20 13:20 - Deivid: Un fenómeno
# +++18/3/20 13:20 - Deivid: Tuuuu tengo el rocket pero no online
# +++18/3/20 13:20 - Deivid: Por ser pirata
# +++18/3/20 13:20 - Ander: Jajajjajajja no siempre que te lo descargas ilegal es sin online
# +++18/3/20 13:21 - Ander: un crack eh😅😅
# +++18/3/20 13:41 - Deivid: Que le follen me dejo 20 pavos
# +++18/3/20 13:42 - Nano: JAJAJAJAJA
# +++18/3/20 13:42 - Nano: <Multimedia omitido>
# +++18/3/20 13:42 - Deivid: Siiiii lo se
# +++18/3/20 19:10 - Deivid: Nano
# +++18/3/20 19:10 - Deivid: Ander
# +++18/3/20 19:10 - Deivid: Si quereis jugar
# +++18/3/20 19:10 - Deivid: Que sea ahora
# +++18/3/20 19:10 - Deivid: Antes de mi gym
# +++18/3/20 19:11 - Ander: Si tu gym es ahora no?
# +++18/3/20 19:11 - Ander: Yo estoy jugando
# +++18/3/20 19:11 - Deivid: Cambio de planes😂😂😂
# +++18/3/20 19:11 - Deivid: Voy
# +++18/3/20 19:11 - Deivid: Como te agrego?
# +++18/3/20 19:11 - Nano: Jajaja
# +++18/3/20 19:11 - Nano: Voy, pillo la play
# +++18/3/20 19:13 - Ander: Me tienes que decir tu RocketID
# +++18/3/20 19:14 - Deivid: Estoy buscando el juego
# +++18/3/20 19:14 - Deivid: Jajajaja
# +++18/3/20 19:14 - Deivid: Que no se donde lo he metido
# +++18/3/20 19:14 - Deivid: Estar esta
# +++18/3/20 19:15 - Deivid: Que ya he jugado
# +++18/3/20 19:17 - Deivid: Donde lo veo ander
# +++18/3/20 19:18 - Ander: A mi me sale en agregar
# +++18/3/20 19:18 - Ander: Yo soy Bilbogamer27#7762
# +++18/3/20 19:19 - Nano: Invitame otra vez ander
# +++18/3/20 19:20 - Deivid: <Multimedia omitido>
# +++18/3/20 19:20 - Nano: Llamamos por skype?
# +++18/3/20 19:20 - Deivid: Yeees
# +++18/3/20 19:21 - Deivid: Te acabo de enviar invita ander
# +++18/3/20 19:23 - Deivid: Ulaaaa?
# +++18/3/20 19:24 - Nano: Estoy descargándome skype
# +++18/3/20 19:25 - Ander: En el móvil o donde lo vais a poner?
# +++18/3/20 19:26 - Deivid: Ipa
# +++18/3/20 19:26 - Deivid: Pad
# +++18/3/20 19:27 - Nano: Agregame dave y te invito
# +++18/3/20 19:28 - Deivid: A q?
# +++18/3/20 19:28 - Deivid: Skype
# +++18/3/20 19:28 - Deivid: O rocket
# +++19/3/20 0:18 - Nano: Acabo de echarme un clubes pro con el hijo del cholo
# +++19/3/20 0:18 - Nano: JAJAJA
# +++19/3/20 0:18 - Nano: El giuliano
# +++19/3/20 0:27 - Ander: Ostias, partido a partido
# +++19/3/20 18:19 - Deivid: Dado
# +++19/3/20 18:19 - Deivid: Te echas unos rocket?
# +++19/3/20 18:19 - Deivid: 😏
# +++19/3/20 18:25 - Nano: Estaba editando una shit
# +++19/3/20 18:25 - Nano: 3 mins y le doy
# +++19/3/20 18:25 - Nano: Estás con Andres?
# +++19/3/20 18:25 - Deivid: Seeeh
# +++19/3/20 18:30 - Nano: Voy
# +++19/3/20 18:30 - Nano: Llamame
# +++24/3/20 22:25 - Adiran: <Multimedia omitido>
# +++24/3/20 22:28 - Deivid: Que cojones adiran?😂😂
# +++24/3/20 22:45 - Adiran: tu tiene que doler una barbaridad
# +++27/3/20 1:01 - Adiran: <Multimedia omitido>
# +++27/3/20 1:01 - Adiran: <Multimedia omitido>
# +++27/3/20 1:01 - Adiran: <Multimedia omitido>
# +++27/3/20 1:01 - Adiran: <Multimedia omitido>
# +++27/3/20 9:06 - Deivid: 😂😂😂
# +++27/3/20 9:06 - Deivid: El de la mujer es muy basto
# +++27/3/20 9:32 - Wilf: Riley Reid* jajaja
# +++27/3/20 9:32 - Wilf: A mi me mola el de las gallinas
# +++27/3/20 9:32 - Wilf: 🤣
# +++27/3/20 9:34 - Deivid: Puto pajero
# +++27/3/20 9:35 - Wilf: Sale tambn en los videos de Logan Paul!
# +++27/3/20 9:36 - Deivid: <Multimedia omitido>
# +++27/3/20 9:36 - Deivid: <Multimedia omitido>
# +++27/3/20 9:36 - Deivid: <Multimedia omitido>
# +++27/3/20 9:36 - Deivid: <Multimedia omitido>
# +++27/3/20 9:53 - Adiran: Mazo
# +++27/3/20 9:54 - Adiran: Como se las sabe el eilf
# +++27/3/20 9:54 - Adiran: Que cojas
# +++28/3/20 21:29 - Adiran: <Multimedia omitido>
# +++28/3/20 23:23 - Adiran: THE QUARANTINE GAME! The goal is to fuck Ariane, Let's see who can do it: https://www.datingariane.com
# +++28/3/20 23:24 - Adiran: Tu es jodidisimo
# +++28/3/20 23:24 - Adiran: Yo estoy en el 5 intento y no lo logro
# +++29/3/20 13:57 - Wilf: Jajajq primer intento
# +++29/3/20 13:57 - Wilf: Hoyo
# +++29/3/20 13:57 - Wilf: Jajaja
# +++29/3/20 13:57 - Adiran: Tu yo ayer me tire 20 intentos y nada
# +++29/3/20 13:57 - Adiran: Incluso me la lleve al jacuzzi
# +++29/3/20 14:04 - Wilf: Jajajaja
# +++29/3/20 14:04 - Wilf: Llevo 3 intentos
# +++29/3/20 14:08 - Wilf: Se le esta yendo de las manos
# +++29/3/20 14:08 - Wilf: Estoy en la ciudad haciendo un tour en un museo😂
# +++29/3/20 14:08 - Adiran: Bua mala señal bro
# +++29/3/20 14:08 - Wilf: <Multimedia omitido>
# +++29/3/20 14:08 - Adiran: Has ido al sitio de las hamburguesas?
# +++29/3/20 14:08 - Wilf: Ayuda
# +++29/3/20 14:08 - Wilf: Si
# +++29/3/20 14:08 - Wilf: 😂
# +++29/3/20 14:09 - Adiran: Bua te va a dejar plantado que flipas
# +++29/3/20 14:09 - Wilf: Jajajajajajajaja😂
# +++29/3/20 14:09 - Adiran: Si te dice fe ir al parque de atracciones dile que no
# +++29/3/20 14:09 - Wilf: Vale
# +++29/3/20 14:09 - Wilf: Y al parque?
# +++29/3/20 14:09 - Wilf: Nos hemos columpiado
# +++29/3/20 14:09 - Adiran: Boticelli
# +++29/3/20 14:09 - Wilf: Y parecia que ibamos bien
# +++29/3/20 14:09 - Wilf: Jajaka
# +++29/3/20 14:09 - Adiran: Ahi no fui
# +++29/3/20 14:09 - Wilf: Ahora estoy aqui
# +++29/3/20 14:09 - Wilf: Grande!
# +++29/3/20 14:09 - Wilf: <Multimedia omitido>
# +++29/3/20 14:10 - Wilf: Y esta?
# +++29/3/20 14:10 - Adiran: En verdad me lo he inventado
# +++29/3/20 14:10 - Wilf: Has acertado!
# +++29/3/20 14:10 - Wilf: 😂
# +++29/3/20 14:10 - Adiran: Yo diria rembrandt o michelangelo
# +++29/3/20 14:10 - Adiran: Es que me sonaba a boticelli, por el estilo y tal
# +++29/3/20 14:11 - Adiran: Muy de siglo 14-15 o por ahi
# +++29/3/20 14:11 - Wilf: En la psicina bro
# +++29/3/20 14:11 - Wilf: 😂
# +++29/3/20 14:11 - Wilf: Vamos bien
# +++29/3/20 14:11 - Adiran: Vava dale
# +++29/3/20 14:11 - Adiran: Si has esquivado el parque de tracciones vas bien
# +++29/3/20 14:12 - Adiran: Yo hice una carrera y la deje ganar
# +++29/3/20 14:12 - Adiran: Pero no se si es bueno porque a mi no me ha salido
# +++29/3/20 14:13 - Adiran: Llevatela al jacuzzi despues
# +++29/3/20 14:13 - Adiran: Y juega a verdad o atrevimiento
# +++29/3/20 14:28 - Ander: Yo lo conseguí ayer😉
# +++29/3/20 14:29 - Wilf: Sisi
# +++29/3/20 14:29 - Wilf: Yo tambn he hecho eso
# +++29/3/20 14:29 - Wilf: <Multimedia omitido>
# +++29/3/20 14:29 - Wilf: <Multimedia omitido>
# +++29/3/20 14:29 - Wilf: Me estoy mofando😂
# +++29/3/20 14:29 - Wilf: <Multimedia omitido>
# +++29/3/20 14:29 - Wilf: JAJAJAJAJAA
# +++29/3/20 14:29 - Tom: Buen puño wilf
# +++29/3/20 14:29 - Wilf: Que me matan
# +++29/3/20 14:30 - Ander: Ahi vas bien bro
# +++29/3/20 14:30 - Tom: Pégale
# +++29/3/20 14:30 - Adiran: Jajajajajaja
# +++29/3/20 14:32 - Nano: Que cojones
# +++29/3/20 14:32 - Nano: Jajaja
# +++29/3/20 14:32 - Nano: Vaya puto animal
# +++29/3/20 14:34 - Adiran: Tu que cabron
# +++29/3/20 16:07 - Wilf: Suuu
# +++29/3/20 16:07 - Wilf: Conseguido jajaja
# +++29/3/20 16:08 - Wilf: Cenar pizza, ir a la playa, hacer el pino en la playa , volver a casa y bailar
# +++29/3/20 16:08 - Wilf: Y ya a partir de ahi te da pistas jajaja
# +++29/3/20 16:10 - Wilf: Y en la pizza se manche  dejala que se vaya al dormitoorio
# +++29/3/20 16:11 - Wilf: Pq el resto son hoyazos jajaja
# +++29/3/20 16:14 - Ander: Yo no lo hice asi
# +++29/3/20 16:14 - Ander: Nunca había ido a la playa
# +++29/3/20 16:14 - Ander: 😅😅
# +++29/3/20 16:16 - Wilf: El juego es flipante ehh jajaja
# +++29/3/20 16:16 - Wilf: Quiero decir, hay mazo escenarios
# +++29/3/20 16:16 - Adiran: Os paso cosas de calidad chavales
# +++29/3/20 16:16 - Adiran: Jajajaja
# +++29/3/20 16:16 - Wilf: Esta gracioso
# +++29/3/20 16:16 - Wilf: No me esperaba que tuviera tantas opciones
# +++29/3/20 16:20 - Wilf: Puedes jugar hasta el parchis😂
# +++29/3/20 16:25 - Wilf: Ahora jugando al basket
# +++29/3/20 16:25 - Wilf: Me descojono
# +++29/3/20 17:17 - Adiran: https://www.reddit.com/r/nextfuckinglevel/comments/fr3fbq/this_guy_raised_the_level_in_dating_wherever_you/?utm_medium=android_app&utm_source=share
# +++29/3/20 19:54 - Wilf: Que bonita historia
# +++29/3/20 19:54 - Wilf: El tio es un mofao
# +++29/3/20 19:56 - Deivid: Ya ves jjajajaja
# +++29/3/20 19:56 - Deivid: Que jefe
# +++29/3/20 19:56 - Deivid: Calleja toma nota broder
# +++29/3/20 19:56 - Deivid: A ver si enamoras a una mozuela
# +++29/3/20 19:57 - Wilf: Mejor de tranquis un dia normal
# +++29/3/20 19:57 - Deivid: Que poco romantico wilf
# +++29/3/20 19:57 - Wilf: Comprar un dron no renta
# +++29/3/20 19:57 - Wilf: Jajaja
# +++29/3/20 19:58 - Deivid: <Multimedia omitido>
# +++29/3/20 19:58 - Deivid: Naj calleja le tira un bolazo  con la raqueta de padel y con su número escrito y es igual de eficaz
# +++29/3/20 19:59 - Wilf: Jajajajaja
# +++29/3/20 20:41 - Adiran: Jajajaj
# +++30/3/20 15:25 - Nano: <Multimedia omitido>
# +++30/3/20 15:25 - Ander: Espectacular
# +++30/3/20 15:25 - Adiran: JAJAJAJAJJA que basto
# +++30/3/20 15:25 - Adiran: Jajajaja
# +++30/3/20 15:26 - Nano: Es un 10
# +++30/3/20 15:32 - Ander: https://www.instagram.com/s/aGlnaGxpZ2h0OjE3ODU5MTM2MTUwODExNjE3?igshid=1k0dnhao8hl4p&story_media_id=2274097963100328710_205972788
# +++30/3/20 15:33 - Adiran: Jajajaja es el ultimate video
# +++30/3/20 15:33 - Ander: Hay 200 historias de auronplay de ese tipo de video eh
# +++30/3/20 15:33 - Ander: Algunas son brutales
# +++30/3/20 15:38 - Nano: Pero 200
# +++30/3/20 15:39 - Tom: Vaya hostias tío
# +++30/3/20 15:40 - Ander: Algunos son increíbles eh
# +++30/3/20 17:56 - Nano: Muy bestias
# +++30/3/20 17:56 - Nano: Pero muy bestias
# +++1/4/20 0:21 - Tom: https://youtu.be/gI-WJHsIoKE
# +++1/4/20 0:21 - Tom: Escuchadlo con auriculares
# +++1/4/20 0:21 - Tom: Nuevo tema de un colega dadle apoyo
# +++1/4/20 1:09 - Tom: Escuchado
# +++1/4/20 1:10 - Tom: Lo habéis escuchado?
# +++1/4/20 1:14 - Adiran: Yo ahora cuando pille cascos
# +++1/4/20 1:15 - Adiran: El otro dia escuche uno de esos y son increibles
# +++1/4/20 1:20 - Adiran: Bua esta muy guapo
# +++1/4/20 1:21 - Adiran: https://m.youtube.com/watch?v=yHKcExQTQa0
# +++1/4/20 1:21 - Adiran: https://youtu.be/IUDTlvagjJA
# +++1/4/20 14:38 - Calleja: No he entrado pero me fio 0
# +++1/4/20 15:17 - Adiran: <Multimedia omitido>
# +++1/4/20 15:18 - Adiran: Tu son muy buenos
# +++1/4/20 15:59 - Nano: <Multimedia omitido>
# +++1/4/20 15:59 - Nano: <Multimedia omitido>
# +++1/4/20 15:59 - Nano: Son muy mofas
# +++1/4/20 16:03 - Deivid: Escándalosos los dos😂😂
# +++1/4/20 16:16 - Nano: <Multimedia omitido>
# +++1/4/20 16:34 - Deivid: Gooooooooool
# +++1/4/20 21:04 - Adiran: Jajajajajja
# +++1/4/20 21:04 - Adiran: Y este es muy bueno tambien
# +++3/4/20 19:27 - Tom: <Multimedia omitido>
# +++3/4/20 19:27 - Tom: <Multimedia omitido>
# +++3/4/20 19:27 - Tom: <Multimedia omitido>
# +++3/4/20 19:27 - Tom: <Multimedia omitido>
# +++3/4/20 19:30 - Nano: Madre de Dios
# +++3/4/20 19:35 - Deivid: La gente esta muy mal de la cabeza
# +++3/4/20 19:57 - Adiran: https://videos.marca.com/v/0_ziy4xn1h-la-verdad-detras-del-meme-de-los-africanos-que-bailan-con-los-ataudes?uetv_pl=virales&count=1
# +++3/4/20 20:03 - Adiran: Tu el pavo ese esta fatal
# +++3/4/20 20:03 - Adiran: Iba con dos espadas jajajaja
# +++4/4/20 11:48 - Tom: <Multimedia omitido>
# +++4/4/20 12:04 - Deivid: 😂😂
# +++4/4/20 12:04 - Deivid: Tom.no se de donde pollas sacaras los vifeos
# +++4/4/20 12:12 - Nano: Chavales, ayerr jugamos al cards against humanity y fue espectacular
# +++4/4/20 12:12 - Nano: Esta noche os quiero a todos
# +++4/4/20 12:12 - Ander: Jajjajajajajaja
# +++4/4/20 12:12 - Ander: De que va eso?
# +++4/4/20 12:15 - Deivid: Ou mama
# +++4/4/20 12:15 - Deivid: Pero yo a las 11 40 o asi
# +++4/4/20 12:15 - Deivid: Que yo veo dos caps de la casa de papel al día
# +++4/4/20 12:16 - Deivid: Y acabo a esa hora
# +++4/4/20 12:16 - Adiran: Jajajajajajajaja
# +++4/4/20 12:16 - Adiran: Rt
# +++4/4/20 12:16 - Adiran: Muy bueno tom
# +++4/4/20 12:25 - Nano: <Multimedia omitido>
# +++4/4/20 12:56 - Ander: Jajjajaaajajjaja
# +++4/4/20 12:56 - Ander: estoy in
# +++4/4/20 13:21 - Deivid: Bruuuuutal
# +++4/4/20 13:21 - Deivid: Yo tb
# +++4/4/20 22:33 - Ander: Cuando mandeis bros
# +++4/4/20 22:37 - Deivid: Yo 23 30
# +++4/4/20 22:38 - Nano: 11:30 perfe
# +++4/4/20 23:00 - Adiran: Bros yo me uniria mas tarde que estoy en medio de un monopoly
# +++4/4/20 23:01 - Wilf: Hoy no puedo:(
# +++4/4/20 23:01 - Wilf: Proxima me apunto 100%
# +++4/4/20 23:28 - Deivid: Brruutal
# +++4/4/20 23:28 - Deivid: A mi e queda nada
# +++4/4/20 23:28 - Deivid: 8 mins
# +++4/4/20 23:28 - Deivid: Id preparandl
# +++4/4/20 23:33 - Nano: Lo voy creando
# +++4/4/20 23:38 - Calleja: Lo has creado?
# +++4/4/20 23:39 - Nano: Sii
# +++4/4/20 23:40 - Ander: Yo estoy
# +++4/4/20 23:40 - Ander: donde hay que meterse?
# +++7/4/20 15:54 - Nano: Jugamos por la nuit?
# +++7/4/20 17:08 - Calleja: Luego os confirmo
# +++7/4/20 17:09 - Adiran: Yo igual
# +++7/4/20 17:09 - Adiran: Es que mañana tengo examen y es tocho
# +++7/4/20 17:10 - Deivid: Yo depende
# +++7/4/20 17:10 - Deivid: No se si mi fam queria juegos hoy
# +++7/4/20 17:10 - Deivid: Si estáis y no juego me uno
# +++7/4/20 22:07 - Nano: <Multimedia omitido>
# +++7/4/20 22:08 - Nano: Es bestia eh
# +++7/4/20 22:09 - Deivid: Mw cago en mis muertos
# +++7/4/20 22:10 - Ander: Yo sudo
# +++7/4/20 22:11 - Nano: No coño, es gracioso, pero bestia
# +++7/4/20 22:14 - Ander: Voy a ir al infierno
# +++7/4/20 23:54 - Adiran: diiiiios no lo habia visto
# +++7/4/20 23:54 - Adiran: muy bestia
# +++7/4/20 23:54 - Adiran: jajajaja
# +++9/4/20 15:57 - Nano: <Multimedia omitido>
# +++9/4/20 15:57 - Nano: <Multimedia omitido>
# +++9/4/20 15:57 - Nano: <Multimedia omitido>
# +++9/4/20 15:57 - Nano: <Multimedia omitido>
# +++9/4/20 15:57 - Nano: <Multimedia omitido>
# +++9/4/20 15:57 - Nano: <Multimedia omitido>
# +++9/4/20 16:04 - Deivid: Jajjajaa son la polla
# +++9/4/20 16:17 - Adiran: Jajajajajajajja
# +++9/4/20 16:17 - Adiran: Me he mofado con el de helton
# +++9/4/20 16:29 - Nano: El de Campbell es bestial
# +++9/4/20 18:53 - Adiran: https://twitter.com/jorbas_f1/status/1248224354208493569?s=21
# +++10/4/20 19:57 - Adiran: <Multimedia omitido>
# +++11/4/20 14:10 - Nano: <Multimedia omitido>
# +++11/4/20 14:10 - Nano: Cura para el coronavirus
# +++11/4/20 14:12 - Adiran: buffffffff
# +++11/4/20 14:12 - Adiran: ou mama
# +++11/4/20 14:19 - Deivid: Qye caaaaaabron
# +++11/4/20 14:32 - Calleja: 😰😰
# +++15/4/20 18:38 - Adiran: https://twitter.com/elmundotoday/status/1250439011128070152?s=12
# +++15/4/20 18:39 - Deivid: 😂😂😂
# +++15/4/20 18:39 - Deivid: Pobre ramos
# +++15/4/20 18:39 - Deivid: Siempre pilla
# +++15/4/20 18:43 - Nano: JAJAJAJAJAJAJJAA
# +++20/4/20 17:42 - Nano: https://www.youtube.com/watch?v=ROdGk9ENL1U
# +++20/4/20 17:42 - Nano: Esta mierda es espectacular
# +++20/4/20 17:52 - Deivid: Luego lo veo
# +++20/4/20 17:52 - Deivid: Tiene pintaza
# +++22/4/20 19:33 - Adiran: <Multimedia omitido>
# +++22/4/20 19:54 - Deivid: Jjajajaja
# +++22/4/20 19:54 - Deivid: Es buenísimo
# +++22/4/20 19:55 - Nano: JAJAJAJ un diez
# +++22/4/20 19:55 - Wilf: JAJAJA😂
# +++25/4/20 12:30 - Nano: Este mensaje fue eliminado
# +++25/4/20 12:31 - Nano: https://depor.com/depor-play/videojuegos/juegos-gratis-descarga-monopoly-plus-gratis-gracias-a-ubisoft-coronavirus-noticia/
# +++26/4/20 13:39 - Adiran: uuuu
# +++26/4/20 13:40 - Adiran: yo me lo descargo jajaja
# +++26/4/20 19:29 - Adiran: <Multimedia omitido>
# +++26/4/20 19:29 - Adiran: <Multimedia omitido>
# +++26/4/20 19:51 - Deivid: Me cago en mi puta vida😂😂😂
# +++26/4/20 20:02 - Wilf: Hostias!
# +++26/4/20 20:13 - Nano: Mi puta madre
# +++26/4/20 20:13 - Nano: Jajaja
# +++27/4/20 16:13 - Deivid: https://youtu.be/prp0dkLYMFY
# +++27/4/20 22:00 - Adiran: Jqjqjajqjajajajajajajaja
# +++28/4/20 15:38 - Nano: <Multimedia omitido>
# +++28/4/20 16:07 - Adiran: Joe tio, pues lo siento porque son momentos jodidos. Aunque si al final lo has decidido tu y piensas que es lo mejor pues no hay vuelta de tuerca.
# +++28/4/20 16:08 - Adiran: Ya sabes que si necesitas cualquier cosa aqui estamos 💪🏼💪🏼
# +++28/4/20 16:08 - Adiran: Y podriamos jugar una de cartas este finde o antes
# +++28/4/20 16:08 - Wilf: Joo Nano
# +++28/4/20 16:08 - Wilf: Lo siento tio
# +++28/4/20 16:08 - Wilf: Si quieres hablarlo
# +++28/4/20 16:08 - Wilf: Yo encantado
# +++28/4/20 16:09 - Wilf: Mucho animo
# +++28/4/20 16:09 - Wilf: Viernes
# +++28/4/20 16:09 - Wilf: Reservad dia
# +++28/4/20 16:11 - Deivid: Animo broder!! Si tu estas bien nosotros estamos bien💪🏼. Por mi el viernes me renta jugar tb como dice wilf
# +++28/4/20 16:26 - Ander: Pues broder si tu estas bien eso es lo importante, y si has tomado esa decisión tendrás mas que motivos de sobra. Mucho animo y el viernes nos vemos😘
# +++28/4/20 17:29 - Nano: Gracias chavalitros. Sí, yo estoy bien pero no deja de ser jodido
# +++28/4/20 17:29 - Nano: Unas cartas cuando queráis 🤘
# +++28/4/20 17:30 - Deivid: chavales por mi nos compramos el monopoly que cuesta 6 pavis
# +++28/4/20 17:30 - Deivid: y podemos jugar cuando queramsos
# +++28/4/20 17:31 - Nano: Yo inn
# +++28/4/20 17:39 - Deivid: el resto?
# +++28/4/20 17:39 - Ander: yo tambien. me la pela el juego
# +++28/4/20 17:42 - Calleja: Lo que querais
# +++28/4/20 17:43 - Deivid: pues pilladlo cuando podais no vaya a subir el precio
# +++28/4/20 17:43 - Deivid: el viernes se juega
# +++28/4/20 17:44 - Calleja: Pero ess de ordenador?
# +++28/4/20 17:44 - Calleja: Osea app u online
# +++28/4/20 17:44 - Deivid: app
# +++28/4/20 17:45 - Deivid: metete en lo que paso nano
# +++28/4/20 17:45 - Deivid: hace unos dias
# +++28/4/20 17:47 - Nano: Lo compro?
# +++28/4/20 17:47 - Deivid: sisi
# +++28/4/20 17:47 - Calleja: Yo no puedo
# +++28/4/20 17:47 - Deivid: yo lo pillo ahora
# +++28/4/20 17:47 - Calleja: pero no os ralleis
# +++28/4/20 17:47 - Deivid: por
# +++28/4/20 17:47 - Deivid: ?
# +++28/4/20 17:47 - Calleja: No computer
# +++28/4/20 17:47 - Deivid: no tienes ordenador
# +++28/4/20 17:47 - Deivid: mira ipad
# +++28/4/20 17:47 - Deivid: ??
# +++28/4/20 17:48 - Calleja: Hay uno que vale 5 pavos
# +++28/4/20 17:48 - Deivid: ordenador o ipad o q?
# +++28/4/20 17:48 - Deivid: y pq no tienes ordenador?
# +++28/4/20 17:49 - Deivid: aunque sea de empresa es un gb el juego
# +++28/4/20 17:49 - Deivid: no es nah
# +++28/4/20 17:49 - Deivid: luego cuando devuelvs el ordenador lo borras
# +++28/4/20 17:49 - Calleja: Ya pero no puedo descargar apps
# +++28/4/20 17:49 - Deivid: intentalo con lo que paso nano
# +++28/4/20 17:50 - Calleja: No me deja descargar apps
# +++28/4/20 17:51 - Deivid: supongo que lo habras intentado
# +++28/4/20 17:51 - Calleja: No me deja descargar apps
# +++28/4/20 17:51 - Deivid: no se como lo caparan
# +++28/4/20 17:51 - Deivid: que pesado
# +++28/4/20 17:51 - Deivid: seguro que puedes modificar eso
# +++28/4/20 17:51 - Calleja: El del ipad tiene güena pinta
# +++28/4/20 17:51 - Deivid: va
# +++28/4/20 17:51 - Deivid: pero vale para ordena=
# +++28/4/20 17:51 - Deivid: ?
# +++28/4/20 17:52 - Deivid: mandalo
# +++28/4/20 17:52 - Calleja: No tiene pinta
# +++28/4/20 17:52 - Deivid: dale al link de nano desde el ipad
# +++28/4/20 17:52 - Deivid: intenta
# +++28/4/20 17:54 - Calleja: No see puede
# +++28/4/20 17:54 - Deivid: no te pueden dejar un fuckin ordenador en tu casa
# +++28/4/20 17:54 - Deivid: jajajaa
# +++28/4/20 18:21 - Calleja: No creo
# +++28/4/20 18:25 - Deivid: bueno busca alguna solucion adna
# +++28/4/20 18:28 - Nano: Hay una versión de play
# +++28/4/20 18:28 - Nano: No sé si es compatible
# +++28/4/20 18:28 - Deivid: ojooooooo
# +++28/4/20 18:28 - Deivid: nano esta al dia
# +++28/4/20 18:28 - Deivid: jajaja
# +++29/4/20 9:18 - Deivid: Buenos dias mis bros
# +++29/4/20 9:18 - Deivid: Al final pillasteis el juego?
# +++29/4/20 9:18 - Deivid: Calle, tu has pensado alguna alternativa?
# +++29/4/20 11:27 - Nano: Yo estoy a la espera de que confirméis
# +++29/4/20 11:27 - Wilf: <Multimedia omitido>
# +++29/4/20 11:56 - Deivid: Nono en el ordenador
# +++29/4/20 11:56 - Deivid: Es mejor para todos
# +++29/4/20 11:56 - Deivid: Pero calle busca alternativas
# +++29/4/20 11:56 - Deivid: Yo tampoco tengo la play
# +++29/4/20 11:57 - Calleja: Cuando pueda miro
# +++29/4/20 13:52 - Adiran: Yo hoy ya puedo cogerlo
# +++29/4/20 13:52 - Adiran: Que he estado bastante liado que tenia 2 trabajos gordos para ayee
# +++29/4/20 13:57 - Wilf: <Multimedia omitido>
# +++29/4/20 14:37 - Deivid: Grande wiiilf
# +++29/4/20 14:37 - Deivid: Vamos a esperar al tontin de calleja
# +++29/4/20 15:03 - Adiran: Jajajajajaja
# +++30/4/20 20:04 - Adiran: <Multimedia omitido>
# +++30/4/20 20:04 - Adiran: <Multimedia omitido>
# +++30/4/20 20:06 - Tom: Esa copita del rey
# +++30/4/20 20:11 - Deivid: Bruuuuutal
# +++30/4/20 20:12 - Deivid: Te quiero adiran
# +++30/4/20 20:27 - Adiran: Tu puede estar brutal hacerse una alubias con chorizo carnecita etx
# +++30/4/20 22:25 - Nano: Que guapísimo
# +++30/4/20 22:25 - Nano: Chavales, me he descargado hoy TikTok
# +++30/4/20 22:26 - Nano: Me estoy partiendo la polla a unos niveles
# +++30/4/20 22:26 - Nano: Escandaloso
# +++30/4/20 22:29 - Deivid: Mañana ni Monopoly ni ostias no?
# +++30/4/20 22:29 - Deivid: Puto calleja
# +++30/4/20 22:37 - Nano: Por mi siii
# +++30/4/20 22:40 - Ander: Yo si
# +++30/4/20 23:32 - Deivid: Calleja no entiendo pq no respondes tio
# +++30/4/20 23:33 - Wilf: <Multimedia omitido>
# +++30/4/20 23:34 - Calleja: Basically
# +++30/4/20 23:34 - Calleja: <Multimedia omitido>
# +++30/4/20 23:34 - Deivid: Que ya lo se
# +++30/4/20 23:34 - Calleja: <Multimedia omitido>
# +++30/4/20 23:34 - Wilf: 😂
# +++30/4/20 23:35 - Deivid: una de dos
# +++30/4/20 23:35 - Deivid: O jugmmos sin calle
# +++30/4/20 23:35 - Deivid: O nos dices alguna alternativa que puedas jugar
# +++30/4/20 23:41 - Nano: JAJAJAJA
# +++30/4/20 23:41 - Nano: Mañana no?
# +++30/4/20 23:45 - Adiran: Jajaja
# +++1/5/20 15:31 - Adiran: <Multimedia omitido>
# +++1/5/20 15:31 - Adiran: <Multimedia omitido>
# +++1/5/20 15:34 - Adiran: <Multimedia omitido>
# +++1/5/20 15:35 - Deivid: Me cago en mi vida
# +++1/5/20 15:35 - Deivid: Dame 5 mins y estoy ahi
# +++1/5/20 15:37 - Nano: Me cago en mi puta madre
# +++1/5/20 15:43 - Ander: Ouuuu mama...😍
# +++1/5/20 15:43 - Deivid: Adiran
# +++1/5/20 15:43 - Deivid: Abreme
# +++1/5/20 16:11 - Nano: <Multimedia omitido>
# +++1/5/20 16:16 - Deivid: 😂😂😂😂😂😂
# +++1/5/20 19:17 - Adiran: Jajajaja
# +++1/5/20 20:05 - Adiran: A que hora hablamos?
# +++1/5/20 21:16 - Wilf: 22:30:)
# +++1/5/20 21:25 - Calleja: 11 30
# +++1/5/20 21:30 - Adiran: Va
# +++1/5/20 21:31 - Nano: Yo como calleja
# +++1/5/20 21:35 - Deivid: Tu pero que decis?
# +++1/5/20 21:35 - Deivid: Yo a las 12 15 estoy metiendome en la cama
# +++1/5/20 21:35 - Deivid: Yo tengo q chapar mañana
# +++1/5/20 21:35 - Deivid: Tengo 3 exams
# +++1/5/20 21:35 - Deivid: La semana que viene
# +++1/5/20 21:43 - Nano: Bro, duermes de 2 a 8:30-9
# +++1/5/20 21:43 - Nano: Como haceeemos tofos
# +++1/5/20 21:43 - Nano: Que tienes 21 años desgraciao
# +++1/5/20 21:49 - Calleja: Yo tengo pocha hasta esa hora
# +++1/5/20 21:52 - Wilf: Yo estoy con Dave😂
# +++1/5/20 21:52 - Wilf: Debo dormir 8 horas
# +++1/5/20 21:52 - Wilf: Y no solo eso
# +++1/5/20 21:53 - Wilf: Sino q mis vecinos son un coñazo y se han quejado alguna vez de mi
# +++1/5/20 21:53 - Wilf: Pq segun parece gritp bastante cuando hago videos
# +++1/5/20 21:53 - Wilf: 😂
# +++1/5/20 21:54 - Wilf: <Multimedia omitido>
# +++1/5/20 21:54 - Wilf: Me ha hecho gracia
# +++1/5/20 21:54 - Wilf: Jajaja
# +++1/5/20 22:01 - Adiran: Jajajajajja
# +++1/5/20 22:01 - Adiran: Siempre me pregunto quien hara estos videos jajajaja
# +++1/5/20 22:16 - Deivid: Ni de coña
# +++1/5/20 22:17 - Deivid: A Este tio le voy pegar
# +++1/5/20 22:17 - Deivid: Osea quedamos hace 5 dias
# +++1/5/20 22:17 - Deivid: No puede descargarse el Monopoly
# +++1/5/20 22:17 - Deivid: Te zumbo
# +++1/5/20 22:17 - Deivid: Ya te lo digo
# +++1/5/20 23:18 - Calleja: Bueno hablamos en 10 no?
# +++1/5/20 23:32 - Deivid: Que usamos?
# +++1/5/20 23:35 - Calleja: Facebook
# +++1/5/20 23:39 - Wilf: Estaus?
# +++1/5/20 23:40 - Ander: Suuu
# +++1/5/20 23:41 - Deivid: Suuu
# +++1/5/20 23:41 - Wilf: <Multimedia omitido>
# +++1/5/20 23:44 - Deivid: Andres
# +++1/5/20 23:44 - Deivid: Me has llamado
# +++1/5/20 23:44 - Deivid: Pero no entro
# +++2/5/20 15:49 - Nano: https://vm.tiktok.com/c1NXSF/
# +++2/5/20 16:03 - Deivid: Chiquita fumada
# +++2/5/20 16:30 - Nano: Desfase eh
# +++2/5/20 20:00 - Calleja: Alguien tira al monte del pilar?
# +++2/5/20 21:24 - Deivid: Yo me he quedado en casita
# +++2/5/20 21:24 - Deivid: Sorru calle
# +++2/5/20 21:24 - Deivid: Que tal estaba el monte?
# +++2/5/20 21:46 - Calleja: Pues como muy metido en primavera
# +++2/5/20 21:49 - Tom: Me he cruzado con el Mono Burgos
# +++2/5/20 21:49 - Tom: Se va al Madrid con Zidane me ha dicho
# +++2/5/20 21:49 - Ander: Yo si que te voy a meter en primavera
# +++2/5/20 21:50 - Calleja: Mañana vamos todos los que podamos no seais cabrones
# +++2/5/20 21:50 - Ander: Que no se puede ir juntos anima
# +++2/5/20 21:51 - Calleja: Que si
# +++2/5/20 21:51 - Calleja: Que ya dejan
# +++2/5/20 21:51 - Nano: JAJAJAJA
# +++2/5/20 21:51 - Nano: <Multimedia omitido>
# +++2/5/20 21:52 - Nano: Separación y fuera
# +++2/5/20 21:52 - Ander: Ojo un nano salvaje😅😅
# +++2/5/20 21:52 - Ander: Yo no puedo correr
# +++2/5/20 21:53 - Nano: Si hemos andado
# +++2/5/20 21:53 - Calleja: Yo tampoco puedo jajajaj
# +++2/5/20 21:55 - Ander: Jajjajajajajaja
# +++2/5/20 21:55 - Ander: Vale pero mañana no puedo, que tengo que mi familia me ha obligado a hacer la cena😰
# +++2/5/20 21:55 - Ander: El lunes estoy dentro
# +++2/5/20 21:57 - Ander: https://www.instagram.com/p/B_A1Vpgo1MZ/?igshid=17sxd3ysbipi5
# +++2/5/20 21:57 - Ander: Ahi lo dejo
# +++2/5/20 22:11 - Deivid: Venga yo mañana me animo
# +++2/5/20 22:11 - Deivid: Pero no me acerco
# +++2/5/20 22:12 - Deivid: Respetamod las distancias
# +++3/5/20 12:01 - Adiran: yo a partir del martes
# +++3/5/20 12:01 - Adiran: que estoy liadisimo con 2 examines y 3 trabajos finales
# +++3/5/20 19:27 - Deivid: Calle
# +++3/5/20 19:27 - Deivid: A las 20 y 10 por el monte?
# +++3/5/20 19:39 - Nano: Dave, yo salgo a las 8 para allá
# +++3/5/20 19:39 - Nano: Te calleo cuando este por el Atleti
# +++3/5/20 19:40 - Ander: Ojo que yo me paso un ratillo💪
# +++3/5/20 19:42 - Deivid: De una
# +++3/5/20 19:42 - Deivid: Nano como me toques te zumbo te aviso
# +++3/5/20 19:42 - Deivid: Que en mi casa nos tienen muy rayaos
# +++3/5/20 19:42 - Deivid: 😂😂🥰
# +++3/5/20 19:42 - Deivid: Mi abuela tiene tol miedo
# +++3/5/20 19:42 - Ander: Yo voy con mascarilla aviso
# +++3/5/20 19:46 - Deivid: a ver, yo llevo mascarilla pero no creo que la lleve todo el rato, te ahogas
# +++3/5/20 19:47 - Calleja: Yo podre a partir de 8 30
# +++3/5/20 19:47 - Nano: <Multimedia omitido>
# +++3/5/20 19:50 - Deivid: jajajajaja
# +++3/5/20 19:50 - Deivid: pq me apetece comerte la boca y necesito que me pares jajaja
# +++3/5/20 19:50 - Deivid: Calle intenta no llegar muy tarde yo sobre las 21 estoy tirando para casa
# +++3/5/20 19:51 - Calleja: Okay
# +++3/5/20 20:14 - Deivid: Yo estoy yendo pal monte ya
# +++3/5/20 20:14 - Calleja: Quedamos en la casa en ruinas?
# +++3/5/20 20:15 - Deivid: Venha
# +++3/5/20 20:18 - Nano: Vikingo siempre llorando
# +++3/5/20 20:18 - Nano: Okele, yo acabo de pasar Mapfre
# +++3/5/20 20:19 - Ander: Donde es eso?
# +++3/5/20 20:20 - Deivid: Por detras de casa de teje
# +++3/5/20 20:20 - Deivid: Hay um camino
# +++3/5/20 20:20 - Deivid: Todo recto
# +++3/5/20 20:20 - Ander: Oookey
# +++3/5/20 20:20 - Ander: yo cuando digáis bajo
# +++3/5/20 20:23 - Deivid: Pero yo estoy en el monte ya
# +++3/5/20 20:23 - Ander: Hostias voy
# +++3/5/20 20:29 - Deivid: Domde andaism
# +++3/5/20 20:29 - Deivid: ?
# +++3/5/20 20:31 - Nano: Acabo de dejar atrás el atleti
# +++3/5/20 20:31 - Nano: 5 mins
# +++3/5/20 20:33 - Deivid: Voy a la casa?
# +++3/5/20 20:33 - Deivid: Es que como no estabais mehe ido a dar un pasele
# +++4/5/20 17:48 - Nano: Vais a caminar luego?
# +++4/5/20 18:53 - Deivid: Nah
# +++4/5/20 18:53 - Deivid: Hoy no
# +++5/5/20 17:14 - Deivid: <Multimedia omitido>
# +++5/5/20 17:14 - Deivid: Nano
# +++5/5/20 17:15 - Deivid: <Multimedia omitido>
# +++5/5/20 17:16 - Adiran: Joder que pinta
# +++5/5/20 17:18 - Deivid: Vamos te cagas
# +++5/5/20 17:21 - Nano: Yaaaaaa ves
# +++5/5/20 17:22 - Nano: Te has puesto como un animal
# +++5/5/20 17:22 - Nano: Que puto hambre
# +++5/5/20 17:24 - Deivid: <Multimedia omitido>
# +++5/5/20 17:25 - Nano: JAJAJAJAJA
# +++5/5/20 17:25 - Nano: Y de postre
# +++5/5/20 17:25 - Nano: Macarrones
# +++5/5/20 17:26 - Nano: Nope bro, como le cambie la receta mi padre me corta la polla
# +++5/5/20 17:27 - Deivid: Vale no le digas nada del beicon
# +++5/5/20 17:27 - Deivid: Jajjajaa
# +++5/5/20 18:21 - Calleja: Hoy sale alguien?
# +++5/5/20 18:24 - Adiran: yo mañana al final chavales
# +++5/5/20 18:25 - Adiran: que pensaba que el examen era por la mañana y es a las 7:00 pm
# +++5/5/20 18:27 - Deivid: Suerte crack
# +++5/5/20 18:27 - Deivid: Yo nop
# +++5/5/20 18:28 - Deivid: Hago gyn en casa
# +++5/5/20 18:28 - Deivid: Q no he podido hacer
# +++5/5/20 18:28 - Deivid: Con mi exam
# +++5/5/20 18:31 - Nano: Calvin, yo no fallo
# +++5/5/20 18:31 - Nano: Saldre 8 de mi keell
# +++5/5/20 18:32 - Calleja: Perfecto
# +++5/5/20 18:32 - Calleja: Bueno te conectas ahora un rato tambien no?
# +++5/5/20 18:34 - Nano: 7 a 8, as always
# +++5/5/20 18:35 - Calleja: Perfect
# +++5/5/20 18:35 - Calleja: Same
# +++6/5/20 15:10 - Wilf: https://youtu.be/wKpC8L_HnG0
# +++6/5/20 15:10 - Wilf: Unexpected
# +++6/5/20 15:11 - Wilf: Recomiendo verse el top 10 al menos jajaj
# +++6/5/20 15:19 - Deivid: Lol estamos el 2
# +++6/5/20 15:19 - Deivid: Es mazo
# +++6/5/20 15:19 - Deivid: Que basto
# +++6/5/20 15:38 - Wilf: Y mas de 80 M
# +++6/5/20 15:38 - Wilf: He flipado jajaja
# +++6/5/20 15:39 - Wilf: Y luego los españoles somos los unicos tontos que decimos que no hay nada q ver en nuestras tierras😂
# +++6/5/20 15:39 - Wilf: Pues eso
# +++6/5/20 15:39 - Wilf: Tontos de remate
# +++6/5/20 15:44 - Tom: Magaluf
# +++6/5/20 15:49 - Wilf: <Multimedia omitido>
# +++6/5/20 15:50 - Wilf: Jqjqjq
# +++6/5/20 17:37 - Adiran: quien sale a caminar hoy?
# +++6/5/20 17:59 - Adiran: Yo sabia que estabamos los segundos pero pensana que italia era primera
# +++6/5/20 18:04 - Nano: Yo saldré pero a las 8:30 de mi kel
# +++6/5/20 19:34 - Calleja: Yo 9
# +++6/5/20 19:41 - Deivid: Yo salgo el viernes chavales
# +++6/5/20 22:32 - Adiran: Perfe
# +++8/5/20 19:34 - Deivid: A q hora hoy?
# +++8/5/20 19:34 - Deivid: Necesito salir
# +++8/5/20 19:38 - Nano: 8:30?
# +++8/5/20 19:38 - Nano: Yo voy en carro que luego me voy a reventar un Burger
# +++8/5/20 19:40 - Deivid: 8 45 casa abandonada?
# +++8/5/20 19:50 - Nano: Debs
# +++8/5/20 19:57 - Adiran: Yo creo que tambien me uno
# +++8/5/20 19:57 - Adiran: Y sii
# +++8/5/20 20:00 - Ander: Broders yo voy a andar solo hasta la estación que el otro día acabe reventao y me dolía la rodilla
# +++8/5/20 20:04 - Deivid: A ver si quieres vernos quedamos en otro lado
# +++8/5/20 20:05 - Ander: Nah no se tampoco vías a hacer todos el mismo recorrido que yo
# +++8/5/20 20:05 - Ander: no pacha nada
# +++8/5/20 20:05 - Ander: Ósea si queréis yo encantado pero es que es la otra direccion
# +++8/5/20 20:06 - Ander: que para arriba hay demasiadas cuestas😰
# +++8/5/20 20:14 - Deivid: Lo que tu digas
# +++8/5/20 20:14 - Deivid: Yo creo que a nosotros no nos importa
# +++8/5/20 20:14 - Deivid: Pero no se
# +++8/5/20 20:14 - Deivid: Calle tu que?
# +++8/5/20 20:16 - Nano: Creoq ue estará dormido
# +++8/5/20 20:16 - Nano: Porque había Tots y no se ha conectado
# +++8/5/20 20:16 - Adiran: A mi tambien me da igual ander
# +++8/5/20 20:24 - Ander: Pues yo por mi bien
# +++8/5/20 20:24 - Nano: Le he dicho a cris que vamos a estar por el monte
# +++8/5/20 20:25 - Nano: Donde vamos? Para decirla si cambiamos ruta
# +++8/5/20 20:26 - Deivid: Donde digáis
# +++8/5/20 20:27 - Deivid: Quedamos en el parque de detras del supercor?
# +++8/5/20 20:27 - Deivid: Detras del boca grande
# +++8/5/20 20:27 - Deivid: O algo asi se llama
# +++8/5/20 20:29 - Nano: Okele
# +++8/5/20 20:29 - Nano: <Multimedia omitido>
# +++8/5/20 20:29 - Ander: Por mi perfe
# +++8/5/20 20:29 - Ander: Avisa y bajo yo tambien
# +++8/5/20 20:34 - Deivid: Yo estoy ya
# +++8/5/20 20:34 - Deivid: Por aqui
# +++8/5/20 20:35 - Ander: Tuuuuuu avisa cara almendra
# +++8/5/20 20:37 - Nano: Where
# +++8/5/20 20:38 - Deivid: Pero payaso
# +++8/5/20 20:38 - Deivid: Lo de menos 15?
# +++8/5/20 20:38 - Deivid: Estoy en el monte
# +++8/5/20 20:39 - Deivid: Cuando digais voy al parque
# +++8/5/20 20:39 - Nano: Ve
# +++8/5/20 20:41 - Deivid: Voy
# +++8/5/20 20:45 - Nano: Negro, dónde andas?
# +++8/5/20 20:49 - Calleja: Buenos dias
# +++8/5/20 20:49 - Calleja: Saldre en 10
# +++8/5/20 20:49 - Calleja: Mandadme ubi real
# +++8/5/20 20:51 - Deivid: ubicación en tiempo real compartida
# +++9/5/20 20:16 - Calleja: Quedamos a las 9?
# +++9/5/20 20:16 - Adiran: Yo hoy no se si ire chavales
# +++9/5/20 20:16 - Adiran: Que no he salido a correr por la mañana y quiero ir ahora
# +++9/5/20 20:36 - Calleja: El resto?
# +++9/5/20 20:38 - Deivid: Yo no
# +++9/5/20 20:40 - Ander: Yo hoy me fajo tambien
# +++11/5/20 17:44 - Adiran: Alguien hoy?
# +++11/5/20 17:44 - Ander: Yon
# +++11/5/20 17:44 - Ander: Yo* jeje
# +++11/5/20 18:29 - Calleja: Moi
# +++11/5/20 18:49 - Nano: Yo
# +++11/5/20 20:32 - Ander: Avisarme y bajo
# +++11/5/20 20:43 - Calleja: Yo estoy bajando ya
# +++11/5/20 20:43 - Ander: Voy
# +++11/5/20 20:43 - Ander: al parque no?
# +++11/5/20 20:44 - Calleja: Si quieres quedamos en tu casa
# +++11/5/20 20:44 - Calleja: Que nos pilla de camino
# +++11/5/20 20:44 - Ander: Vap
# +++11/5/20 20:46 - Adiran: Yo llego un poco tarde
# +++11/5/20 20:46 - Adiran: Que me he liado
# +++11/5/20 20:46 - Calleja: Va
# +++11/5/20 20:46 - Calleja: Si
# +++11/5/20 20:46 - Adiran: Mandadme ubica y asi voy directo
# +++11/5/20 20:46 - Calleja: ubicación en tiempo real compartida
# +++11/5/20 20:50 - Ander: Gordo, si no has salido de casa😂😂
# +++12/5/20 16:59 - Adiran: Yo hoy no salgo que esta lloviendo
# +++12/5/20 17:49 - Calleja: Tiene mala pinta
# +++12/5/20 17:52 - Nano: Yo si para salgo
# +++12/5/20 17:52 - Nano: Pero pinta feo
# +++12/5/20 20:52 - Ander: https://twitter.com/IbaiLlanos/status/1260216196512788480?s=20
# +++12/5/20 21:47 - Nano: Totalmente de acuerdo con las galletas maria
# +++12/5/20 21:47 - Nano: Sobrevaloradas
# +++12/5/20 21:47 - Nano: Te las revientes en el campamento porque no hay otra
# +++12/5/20 21:55 - Ander: Jajjajajajjajaja si eso si
# +++12/5/20 21:55 - Ander: Pero las oreos es de cárcel eh
# +++12/5/20 22:02 - Nano: Sí, y las Príncipe igual
# +++12/5/20 22:15 - Deivid: Puto ibai
# +++12/5/20 22:15 - Deivid: Las  príncipe son sagradas no jodas
# +++13/5/20 17:53 - Nano: Si aguanta el tiempo yo hoy saldré
# +++13/5/20 18:28 - Ander: Yo hoy no
# +++13/5/20 18:29 - Deivid: Yo me animo hoy
# +++13/5/20 18:29 - Deivid: Me ape
# +++13/5/20 18:49 - Adiran: Yo os digo en un rato pero probablemente si
# +++13/5/20 18:57 - Nano: De locos
# +++13/5/20 19:29 - Calleja: Yo os voy diciendo
# +++13/5/20 19:49 - Deivid: Dado
# +++13/5/20 19:49 - Deivid: A que hora?
# +++13/5/20 19:49 - Deivid: Y donde el otro día no?
# +++13/5/20 19:53 - Nano: As you like
# +++13/5/20 19:53 - Nano: Yo salgo en punto para allá
# +++13/5/20 20:04 - Deivid: Cuanto tardas nano?
# +++13/5/20 20:06 - Nano: En 30 estoy
# +++13/5/20 20:08 - Deivid: Va
# +++13/5/20 20:29 - Nano: Voy por el atleti
# +++13/5/20 20:29 - Nano: Voy a la puerta?
# +++13/5/20 20:33 - Deivid: A nuestra puerta?
# +++13/5/20 20:33 - Deivid: Okey
# +++13/5/20 20:33 - Nano: No coño
# +++13/5/20 20:33 - Nano: La del monte del pilar
# +++13/5/20 20:33 - Nano: Pero donde digas
# +++13/5/20 20:33 - Nano: Calvin?
# +++13/5/20 20:38 - Deivid: Yo estoy en la puerta de mi casa
# +++13/5/20 20:38 - Deivid: Esperando a andres
# +++13/5/20 20:38 - Ander: Toy en 10 secs
# +++13/5/20 20:39 - Nano: Calleja, paso por tu portal en 3 mins
# +++13/5/20 20:39 - Deivid: Vamos al portal de calle
# +++13/5/20 20:57 - Adiran: Yo acabo de salir
# +++13/5/20 20:57 - Adiran: Mandad ubica
# +++14/5/20 17:33 - Adiran: Quien sale hoy?
# +++14/5/20 18:59 - Nano: Yoo
# +++14/5/20 18:59 - Nano: A las 8
# +++14/5/20 18:59 - Nano: More?
# +++14/5/20 19:08 - Adiran: Venga 8
# +++14/5/20 19:08 - Adiran: La hora me da igual
# +++14/5/20 19:11 - Calleja: Yo saldre 9 menos cuarto como ziempre
# +++14/5/20 19:13 - Nano: Lo que tardo en llegar, de locos
# +++14/5/20 19:30 - Adiran: <Multimedia omitido>
# +++14/5/20 19:52 - Wilf: Wtf😂
# +++14/5/20 20:44 - Nano: Llego en un min
# +++14/5/20 20:56 - Adiran: Donde estais?
# +++14/5/20 21:30 - Deivid: Bruuutal
# +++14/5/20 21:30 - Deivid: Me faltaba un soy de bilbao de reno ranardo
# +++15/5/20 15:51 - Wilf: <Multimedia omitido>
# +++15/5/20 15:51 - Wilf: <Multimedia omitido>
# +++15/5/20 15:54 - Deivid: Eso no es nah
# +++15/5/20 15:54 - Deivid: Chavales miraos las dos oartes de la entrevista de salva espín en la resistencia
# +++15/5/20 15:54 - Deivid: Ese tio es mi puto ídolo
# +++15/5/20 16:30 - Adiran: Dios
# +++15/5/20 16:43 - Wilf: Me las he visto
# +++15/5/20 16:43 - Wilf: El dibujante de deadpool no?
# +++15/5/20 16:43 - Wilf: Se le ve super buena persona
# +++15/5/20 16:43 - Deivid: Es de marvel en general
# +++15/5/20 16:43 - Deivid: Pero Deadpool es su obra maestra si
# +++15/5/20 17:26 - Wilf: Chii
# +++15/5/20 20:47 - Calleja: Alguien sale?
# +++16/5/20 14:27 - Adiran: Tu cuales eran las reglas exactas del michigan?
# +++16/5/20 14:27 - Adiran: En plan cuando se podia coger solo un dado y volver a tirar
# +++16/5/20 14:27 - Adiran: Y esas cosas
# +++16/5/20 15:01 - Ander: Si eres el primero siempre tiras 2
# +++16/5/20 15:01 - Ander: Y sino eliges cuantos quieres tirar
# +++16/5/20 15:02 - Ander: Pero el primero elige el numero de veces que tira
# +++16/5/20 15:20 - Adiran: Y en el desempate como funcionaba?
# +++16/5/20 15:39 - Adiran: En el desempate cuantas rondas habia?
# +++16/5/20 16:33 - Ander: Igual
# +++16/5/20 16:33 - Ander: Solo que jugaban los que desempatan solo
# +++16/5/20 18:18 - Calleja: Quiek sale hoy?
# +++16/5/20 18:24 - Nano: Moi
# +++16/5/20 19:16 - Deivid: Yo os voy narrando, si hago deporte con la fam no si no hacen si
# +++16/5/20 19:28 - Adiran: Yo
# +++16/5/20 19:28 - Adiran: Vale gracias
# +++16/5/20 20:19 - Adiran: Hora?
# +++16/5/20 20:24 - Nano: <Multimedia omitido>
# +++16/5/20 20:25 - Ander: Yo hoy no bros
# +++16/5/20 20:31 - Adiran: Okk
# +++16/5/20 20:57 - Nano: Toy
# +++16/5/20 20:57 - Nano: ubicación en tiempo real compartida
# +++16/5/20 21:25 - Deivid: Yo he estado haciendo deporte con la fam locos
# +++17/5/20 12:39 - Adiran: <Multimedia omitido>
# +++17/5/20 12:39 - Adiran: Jajaja
# +++17/5/20 12:39 - Adiran: Puto idolo
# +++17/5/20 12:40 - Adiran: Que ahora se ha vuelto youtuber jajajaja
# +++17/5/20 12:46 - Deivid: Sisi es un fenómeno
# +++17/5/20 12:46 - Deivid: Hay un video que hace la mitica de que se fuma el rotulador
# +++17/5/20 12:46 - Deivid: Es increíble
# +++17/5/20 12:46 - Deivid: Me trae demasiados buenos recuerdos
# +++17/5/20 13:04 - Adiran: Ajjajajjajaja
# +++17/5/20 13:04 - Adiran: Ostia eso no lo sabia
# +++17/5/20 13:04 - Adiran: Tal cual
# +++17/5/20 13:04 - Nano: JAJAJAJAJ
# +++17/5/20 13:05 - Nano: Vaya ídolo
# +++17/5/20 16:06 - Wilf: Alguien me pasa el link?:)
# +++17/5/20 21:55 - Wilf: <Multimedia omitido>
# +++17/5/20 21:55 - Wilf: <Multimedia omitido>
# +++17/5/20 21:55 - Wilf: <Multimedia omitido>
# +++17/5/20 21:55 - Wilf: Majada tanbn creo xd
# +++17/5/20 22:03 - Wilf: <Multimedia omitido>
# +++17/5/20 22:14 - Deivid: Pero uqe quiere hacer exactamente?
# +++17/5/20 22:15 - Wilf: <Multimedia omitido>
# +++17/5/20 22:17 - Deivid: No entiendo nada, y que se  supone que  va a solucionar?
# +++17/5/20 22:17 - Wilf: No se
# +++17/5/20 22:17 - Wilf: Repartir el money
# +++17/5/20 22:17 - Wilf: Para q vaya bien todo jajaja
# +++17/5/20 22:17 - Wilf: A saber
# +++17/5/20 22:17 - Wilf: Es solo una propuesta
# +++17/5/20 22:17 - Wilf: Asi q no pasa nah
# +++17/5/20 22:18 - Nano: Esa es “propuesta” de Podemos y no se puede llevar a cabo por que en el congreso no les apoya ni los de la limpieza
# +++17/5/20 22:19 - Nano: Es sobre el impuesto del 2% a los patrimonios bestias
# +++17/5/20 22:21 - Deivid: Que hijosdepu
# +++17/5/20 22:24 - Adiran: A ver lo de la renta minima tampoco creo que salga, y si sale seria solo lo que dure el corona
# +++17/5/20 22:24 - Adiran: Porque es una tonteria y un subsidio para los vagos
# +++17/5/20 22:25 - Adiran: https://www.google.es/amp/s/www.abc.es/sociedad/abci-peculiar-recibimiento-personal-sanitario-primera-ministra-belga-durante-visita-hospital-202005171411_noticia_amp.html
# +++17/5/20 22:27 - Adiran: Ea de belgica cabron jajaja
# +++17/5/20 22:31 - Adiran: Que ahora hay mazo bulos por ahi
# +++17/5/20 22:31 - Adiran: A mi me llego el otro dia esto
# +++17/5/20 22:31 - Adiran: <Multimedia omitido>
# +++17/5/20 22:34 - Adiran: Y “parece” como que incluso la sexta esta dando la espalda al gobierno y estan denunciando que los medios no pueden publicar todo lo quieren y los numeros reales etc
# +++17/5/20 22:34 - Adiran: Pero el video es del 2015
# +++17/5/20 22:49 - Wilf: Pues el bulo se lo han comido mis padres😅
# +++17/5/20 22:49 - Wilf: Y me lo han pasado ellos xd
# +++17/5/20 22:50 - Wilf: Wow
# +++17/5/20 22:51 - Wilf: Ya me parecia raro que la sexta les criticaran jajaj
# +++17/5/20 23:06 - Adiran: Jajajaja
# +++17/5/20 23:07 - Adiran: 🚨 🚨 fake news
# +++17/5/20 23:07 - Adiran: Que ahora estan dandole a tope
# +++17/5/20 23:07 - Adiran: Y tampoco se trata de eso
# +++17/5/20 23:08 - Adiran: El gobierno ya esta cabando au tumba con las acciones que esta tomando
# +++17/5/20 23:09 - Adiran: No son necesarias maa fake news
# +++18/5/20 18:58 - Deivid: Chavules
# +++18/5/20 18:59 - Deivid: Yo hoy salgo
# +++18/5/20 18:59 - Deivid: A que hora podeis?
# +++18/5/20 18:59 - Deivid: Intentad un poco antes
# +++18/5/20 18:59 - Deivid: Que a ls 9 es tarde
# +++18/5/20 19:15 - Calleja: Yo puedi salir 8 30
# +++18/5/20 19:17 - Nano: Igual
# +++18/5/20 19:20 - Deivid: 8 30 casa calle no?
# +++18/5/20 19:20 - Deivid: Firmamos?
# +++18/5/20 19:21 - Ander: Yo me apunto tambien😁
# +++18/5/20 20:06 - Calleja: 👌🏻👌🏻
# +++18/5/20 20:24 - Adiran: Yo os pillo un pelin despues
# +++18/5/20 20:29 - Nano: Voy por el Atleti, 5 mins
# +++18/5/20 20:37 - Deivid: Tmaos en paseo nano
# +++18/5/20 20:37 - Deivid: No en la puerta
# +++18/5/20 20:37 - Adiran: Acabi de salir, lo que tarde
# +++18/5/20 20:38 - Adiran: Decudme dondd esteis
# +++18/5/20 20:40 - Deivid: ubicación en tiempo real compartida
# +++19/5/20 18:23 - Ander: https://twitter.com/IbaiLlanos/status/1262463998152359938?s=08
# +++19/5/20 18:30 - Deivid: Estoy llorando😂😂😂
# +++19/5/20 18:30 - Deivid: Este tio es mi idodlo
# +++19/5/20 18:30 - Ander: Jajjaaajjajajjaja es brutal eh
# +++19/5/20 18:32 - Nano: JAJAJAJA lo que puede soltar por esa boca
# +++19/5/20 19:46 - Adiran: Yo hoy no salgo
# +++19/5/20 19:47 - Adiran: Jajajajajjajajajakjaa
# +++19/5/20 20:03 - Nano: Yo salgo ahora
# +++21/5/20 18:43 - Adiran: Andamos hoy?
# +++21/5/20 19:07 - Nano: Oui
# +++21/5/20 19:53 - Ander: Yo me apunto tambien
# +++21/5/20 19:58 - Ander: Hora en casa calvin?
# +++21/5/20 20:06 - Adiran: 9? O un pelin antes?
# +++21/5/20 20:21 - Nano: A esa llego
# +++21/5/20 21:00 - Ander: Toy
# +++23/5/20 13:34 - Wilf: La F1 aprueba el hándicap de éxito
# |||
# |||https://www.marca.com/motor/formula1/2020/05/23/5ec8e7f9e2704e7c548b4636.html
# +++23/5/20 13:35 - Wilf: Otro deporte que establece limite!
# +++23/5/20 13:35 - Wilf: Pues la verdad q desde que los estadounidenses compraron la F1
# +++23/5/20 13:36 - Wilf: Han estado pesados con meter limite hasta conseguirlo, 132 millones en el desarollo del coche (esto no incluye en salario de los pilotos y no se que mas)
# +++23/5/20 13:37 - Wilf: En eso Europa y el resto del mundo deberian copiarlo
# +++23/5/20 14:17 - Deivid: Es la polla
# +++23/5/20 15:37 - Adiran: Cierto
# +++24/5/20 18:20 - Calleja: Hoy hay novedades del padel
# +++24/5/20 18:21 - Calleja: Es posible que se pueda 2 vs 2
# +++24/5/20 18:21 - Deivid: Eing?
# +++24/5/20 18:21 - Deivid: Normalemente se juega 2vs2...
# +++24/5/20 18:21 - Adiran: https://www.abc.es/deportes/tenis/abci-verde-para-jugar-padel-y-tenis-dobles-202005241543_noticia.html
# +++24/5/20 18:21 - Calleja: Todavia no es oficial
# +++24/5/20 18:22 - Calleja: Tiene que confirmarlo el consejo de deportes
# +++24/5/20 18:22 - Adiran: Yaya
# +++24/5/20 18:22 - Calleja: En ppio dave no se podia hasta fase 3
# +++24/5/20 18:22 - Adiran: Pero bueno que casi seguro
# +++24/5/20 18:22 - Calleja: Y parecw que a lo mejor mañana se puede
# +++24/5/20 18:22 - Deivid: Aaaamigo
# +++24/5/20 18:22 - Deivid: Yo el viernes juego
# +++24/5/20 18:22 - Deivid: Antes no
# +++24/5/20 18:22 - Deivid: Pero a partir del vierned
# +++24/5/20 18:22 - Deivid: Uno al dia vamos
# +++24/5/20 18:22 - Deivid: 😂😂😂
# +++24/5/20 18:22 - Calleja: Sisi
# +++24/5/20 18:23 - Calleja: La putada es el horario
# +++24/5/20 18:23 - Deivid: Pero tu no crees que tb depende de la urba?
# +++24/5/20 18:23 - Deivid: O en cuanto den el ok
# +++24/5/20 18:23 - Deivid: Podemos exigirlo
# +++24/5/20 18:23 - Deivid: ?
# +++24/5/20 18:23 - Calleja: A ver si
# +++24/5/20 18:24 - Calleja: Pero por ejemplo las de cris y teje abrian mañana
# +++24/5/20 18:24 - Calleja: Y decian que individual por lo que decia el gobierno
# +++24/5/20 18:24 - Calleja: Por tanto imagino que en nada se podra
# ...
# +++17/1/21 19:57 - Adiran: Tengo cerves o sea que no traigais
# +++17/1/21 20:45 - Adiran: Entrad por abajo que esta mejor la entrada
# +++17/1/21 23:42 - Deivid: Brutal partido no?
# +++18/1/21 0:11 - Adiran: Aupa
# +++18/1/21 0:11 - Wilf: Enhorabuena Didi
# +++18/1/21 14:13 - Tom: <Multimedia omitido>
# +++18/1/21 14:15 - Tom: <Multimedia omitido>
# +++18/1/21 14:15 - Tom: Me parto la polla jJajaja
# +++18/1/21 14:15 - Wilf: Jajaja parece gay, vasco, comico y todo a la vez😂
# +++18/1/21 14:16 - Adiran: JAJAJAJAJAJAJA
# +++18/1/21 14:17 - Deivid: Ese tiooo no se durmio ni de coña jajajajaa minimo 3 tolas para bajar esa energía
# +++18/1/21 14:17 - Deivid: La virgen
# +++18/1/21 14:17 - Adiran: Puto iñaki, vaya genio
# +++18/1/21 14:17 - Adiran: Ayer se alcoholizo seguro jajaja
# +++18/1/21 16:24 - Ander: va mas volando que calle en el cumple de dave eh...😅😅
# +++18/1/21 16:26 - Gonzalo Manager: O tu en toro?
# +++18/1/21 16:28 - Ander: calle me gana 100%, ese dia incluso
# +++18/1/21 16:35 - Gonzalo Manager: Ajajajjaa
# +++18/1/21 16:35 - Gonzalo Manager: Un bicho calle
# +++18/1/21 16:35 - Gonzalo Manager: Como en año nuevo
# +++18/1/21 17:29 - Calleja: A mi me recuerdo a un vasco en lyon
# +++18/1/21 17:57 - Ander: Si hombre... Que él puede hablar...😅😅
# +++18/1/21 18:12 - Deivid: Buen cieeego
# +++18/1/21 21:34 - Wilf: <Multimedia omitido>
# +++19/1/21 9:07 - Calleja: El final ajjajajaja
# +++19/1/21 9:20 - Nano: “Eso creo que es un continente” JAJAJA
# +++19/1/21 9:24 - Adiran: Mmw
# +++19/1/21 9:25 - Adiran: La del famoso se lo saben todos jajaja
# +++19/1/21 9:26 - Adiran: JAJAAJAJJAJA
# +++19/1/21 16:13 - Calleja: Quien padel sabado 9 a 10 30?
# +++19/1/21 16:13 - Calleja: Gonzalo y yo in
# +++19/1/21 16:13 - Gonzalo Manager: Yo
# +++19/1/21 16:13 - Gonzalo Manager: Nice
# +++19/1/21 16:21 - Nano: yo
# +++19/1/21 17:14 - Adiran: Yo
# +++19/1/21 18:23 - Calleja: Perfecto
# +++19/1/21 18:23 - Calleja: Repetimos
# +++19/1/21 18:24 - Gonzalo Manager: Nice
# +++21/1/21 20:13 - Wilf: Por cierto
# +++21/1/21 20:13 - Wilf: Hoy he probado el Black Angus
# +++21/1/21 20:13 - Wilf: Y es muy bueno el menu
# +++21/1/21 20:14 - Wilf: <Multimedia omitido>
# +++21/1/21 20:14 - Wilf: <Multimedia omitido>
# +++21/1/21 20:14 - Wilf: Todo eso (2 personas) 30€
# +++21/1/21 20:14 - Wilf: Mejor que brasa y leña la carne en mi opinion
# +++21/1/21 20:17 - Deivid: Donde es?
# +++21/1/21 20:27 - Wilf: Black Angus, al lado del rodilla de Boa
# +++21/1/21 20:38 - Gonzalo Manager: Me renta
# +++21/1/21 20:39 - Gonzalo Manager: El menu es de comer
# +++21/1/21 20:39 - Gonzalo Manager: O a cualquier hora
# +++21/1/21 20:46 - Wilf: Comer
# +++21/1/21 20:48 - Gonzalo Manager: Niceee si tw renta algun dia dime
# +++21/1/21 20:48 - Gonzalo Manager: Que currando desde casa tengo una hora para comwr
# +++21/1/21 21:26 - Wilf: 🥳👌🏻👌🏻
# +++21/1/21 23:27 - Adiran: A mi tambien
# +++21/1/21 23:27 - Adiran: Si es menu todavia mejor
# +++22/1/21 1:05 - Wilf: 🤩
# +++22/1/21 10:58 - Tom: Me apetece pádel hoy y mañana
# +++22/1/21 11:00 - Nano: <Multimedia omitido>
# +++22/1/21 16:15 - Wilf: Yo imposible
# +++22/1/21 16:32 - Gonzalo Manager: Yo el domingo
# +++22/1/21 16:33 - Gonzalo Manager: Si alguien quiere
# +++22/1/21 16:37 - Tom: Vale yo in
# +++22/1/21 16:38 - Tom: Y si queréis cenar o hacer algo el domingo porque es mi cumple también
# +++22/1/21 16:38 - Tom: Comer no puedo
# +++22/1/21 16:40 - Adiran: Cenar!
# +++22/1/21 17:57 - Wilf: Prefiero el lunes, que tengo exam😂
# +++22/1/21 17:57 - Wilf: Pero bueno si es un ratin y lo llevo decente me apunto
# +++23/1/21 10:54 - Tom: <Multimedia omitido>
# +++23/1/21 10:55 - Nano: Nope bro
# +++23/1/21 10:55 - Nano: Has visto?
# +++23/1/21 13:36 - Deivid: Chavales me ofrece Jackson partido de calidad en boa mañana a las 13
# +++23/1/21 13:36 - Deivid: Le falta 1
# +++23/1/21 13:36 - Deivid: Alguien quiere?
# +++23/1/21 14:45 - Deivid: Vale le digo q sudais
# +++23/1/21 14:45 - Deivid: Jajaja
# +++23/1/21 15:24 - Wilf: No se si era futbol o padel
# +++23/1/21 15:24 - Wilf: Pero ya sabias my answer
# +++23/1/21 21:58 - Nano: <Multimedia omitido>
# +++23/1/21 21:58 - Nano: <Multimedia omitido>
# +++23/1/21 21:58 - Nano: Ojo la isla
# +++23/1/21 21:58 - Nano: Y los huevos del colega
# +++23/1/21 22:00 - Gonzalo Manager: Menls mal que hay estos programas
# +++23/1/21 22:00 - Gonzalo Manager: Me hacen sentir cada vez menos mal de como he tratado a algunas mujeres
# +++23/1/21 22:03 - Calleja: Pilladle asco a gonzalo
# +++23/1/21 22:03 - Calleja: Que el nuestro negativo es su positivo
# +++23/1/21 22:05 - Adiran: Joder
# +++23/1/21 22:12 - Tom: Cuánto has ganado gon?
# +++23/1/21 22:12 - Gonzalo Manager: +200
# +++23/1/21 22:12 - Gonzalo Manager: Menos mal que me quede
# +++23/1/21 22:13 - Gonzalo Manager: Estaba en 250 total y me he jugado una mano de 50
# +++23/1/21 22:13 - Gonzalo Manager: La he ganado
# +++23/1/21 22:13 - Gonzalo Manager: Y me he ido
# +++23/1/21 22:13 - Tom: Enorme
# +++23/1/21 22:14 - Deivid: Bro pero esto no puede salir en la tele no?
# +++23/1/21 22:15 - Ander: Se han filtrado ya como tres vídeos pornos de estos
# +++23/1/21 22:16 - Gonzalo Manager: Esta es mi españa
# +++23/1/21 22:16 - Gonzalo Manager: Sin filtro en tele
# +++23/1/21 22:16 - Gonzalo Manager: Como debe ser
# +++23/1/21 22:18 - Nano: No sé
# +++23/1/21 22:18 - Nano: Yo me quedo con su tamaño
# +++23/1/21 22:37 - Tom: <Multimedia omitido>
# +++23/1/21 22:37 - Tom: <Multimedia omitido>
# +++23/1/21 22:38 - Nano: Tocho eh
# +++23/1/21 23:34 - Deivid: La virgen
# +++24/1/21 9:55 - Adiran: Tu no me acordaba que a las 6 no puedo padel
# +++24/1/21 9:55 - Adiran: Podeis adelantarlo/retrasarlo?
# +++24/1/21 10:41 - Calleja: Retrasarlo diria que no
# +++24/1/21 10:41 - Calleja: Adelantarlo por mi si
# +++24/1/21 10:42 - Calleja: Bueno no se tampoco porque Tom tiene comida
# +++24/1/21 10:44 - Gonzalo Manager: Yo adelantar chungo
# +++24/1/21 10:44 - Gonzalo Manager: Seria 5:30
# +++24/1/21 10:50 - Calleja: Adiran que hacemos, contamos contigo o buscamos a otro?
# +++24/1/21 10:51 - Calleja: En plan yo creo que empresar entee 5 30 y 6 30 como tarde
# +++24/1/21 10:52 - Tom: Hace un sol de locos
# +++24/1/21 10:52 - Tom: Gonzalo reservas tú?
# +++24/1/21 10:59 - Adiran: Yo eso no puedo
# +++24/1/21 10:59 - Adiran: Pillad a otro
# +++24/1/21 11:07 - Gonzalo Manager: Ya esta cerrado
# +++24/1/21 11:07 - Gonzalo Manager: Tom a las 6 en mi kelly
# +++24/1/21 11:08 - Tom: Perfecto
# +++24/1/21 11:08 - Tom: A quién habéis pillado?
# +++24/1/21 11:12 - Calleja: Pablo
# +++24/1/21 15:43 - Gonzalo Manager: Tom calleja ya reservado 6PM
# +++24/1/21 17:20 - Gonzalo Manager: Chavales venid 6:15 pls @34608483311 y @34625558528  que he terminado la comida tarde
# +++24/1/21 17:26 - Tom: Ok
# +++26/1/21 14:24 - Wilf: <Multimedia omitido>
# +++26/1/21 14:24 - Wilf: Duda
# +++26/1/21 14:24 - Wilf: De que color veis el vestido?
# +++26/1/21 14:24 - Deivid: Azul
# +++26/1/21 14:24 - Wilf: Vale yo tambn
# +++26/1/21 14:24 - Calleja: Rt
# +++26/1/21 14:24 - Wilf: Se supone que la gente lo ve rosa
# +++26/1/21 14:24 - Wilf: 😂
# +++26/1/21 14:24 - Wilf: A coño
# +++26/1/21 14:25 - Wilf: Si lo pone en el video
# +++26/1/21 14:25 - Wilf: Jajaja
# +++26/1/21 14:26 - Wilf: <Multimedia omitido>
# +++26/1/21 14:58 - Adiran: Yo creo que lo veo azul
# +++26/1/21 14:59 - Adiran: Pero estoy seguro de que la tia tiene polvazo
# +++26/1/21 15:05 - Ander: Pero si tiene 10 años...😅😅
# +++26/1/21 15:05 - Adiran: noooo
# +++26/1/21 15:05 - Adiran: Si?
# +++26/1/21 15:05 - Ander: Y te están vasiloneando eh😅
# +++26/1/21 15:05 - Adiran: Parece mayor
# +++26/1/21 18:04 - Calleja: Alguien jugaria hoy de 8 a 9?
# +++26/1/21 18:10 - Gonzalo Manager: Tengo clase :(
# +++27/1/21 15:17 - Wilf: <Multimedia omitido>
# +++27/1/21 15:20 - Adiran: JAJAJAJAJJAJAJAJAJAJAJJAJAJAJAJAJJAKAJAJAJAJAJAJJAJAJAJAJAJ
# +++27/1/21 15:20 - Adiran: De lo mejor que he visto en mucho tiempo
# +++27/1/21 15:21 - Deivid: Me ha hecho mucha gracia
# +++29/1/21 12:01 - Adiran: Padel alguien mañana a las 7?
# +++29/1/21 12:04 - Calleja: De la tarde?
# +++29/1/21 12:05 - Tom: Haha
# +++29/1/21 12:15 - Adiran: Mañana 💪🏼💪🏼
# +++29/1/21 12:16 - Calleja: No se puede
# +++29/1/21 12:16 - Nano: Yo
# +++29/1/21 12:16 - Nano: Why?
# +++29/1/21 12:16 - Adiran: Justo
# +++29/1/21 12:59 - Gonzalo Manager: Llueve
# +++29/1/21 20:05 - Calleja: Avisad cuando esteis
# +++29/1/21 20:06 - Tom: 2 min
# +++30/1/21 10:40 - Adiran: Alguien padel mañana por la mañana?
# +++30/1/21 10:40 - Calleja: Yo
# +++30/1/21 10:40 - Adiran: 2 more
# +++30/1/21 10:45 - Gonzalo Manager: Tengo por la tarde sorry
# +++30/1/21 11:56 - Deivid: Noup
# +++31/1/21 10:34 - Wilf: <Multimedia omitido>
# +++31/1/21 10:34 - Wilf: No se si sera mentira
# +++31/1/21 10:34 - Wilf: Pero vaya locura
# +++31/1/21 10:35 - Calleja: A ver
# +++31/1/21 10:35 - Calleja: Son 5 años
# +++31/1/21 11:33 - Adiran: Es una pasada
# +++31/1/21 12:37 - Wilf: Son 4 años
# +++31/1/21 12:37 - Wilf: Y las primas de renovacion y de fidelidad son una mofa
# +++31/1/21 12:38 - Wilf: Luego que si tienen problemas economicos
# +++31/1/21 12:38 - Wilf: Que segun parece estan de culo no, lo siguiente
# +++31/1/21 12:38 - Wilf: Y se va a comer el marron el que salga de presidente
# +++31/1/21 12:38 - Wilf: Que Messi genera mazo si, pero el resto fde jugadores nou
# +++31/1/21 12:43 - Adiran: Justo
# +++31/1/21 12:44 - Adiran: Yo creo que aunque genere tanto y sea el mejor no se le puede pagar eso
# +++31/1/21 12:44 - Adiran: Es desproporcionado
# +++31/1/21 12:44 - Adiran: Ahi yo creo que floren lo hace bien
# +++31/1/21 12:45 - Adiran: Si alguien se sube muchísimo a la parra se va
# +++31/1/21 12:46 - Calleja: A ver
# +++31/1/21 12:46 - Calleja: No es justo decir eso
# +++31/1/21 12:47 - Calleja: Messi ha hecho que el barsa suba ese presupuesto
# +++31/1/21 12:47 - Adiran: Que si
# +++31/1/21 12:47 - Calleja: Si el presupuesto es de 900M no esta mal pagarle 140 a messi
# +++31/1/21 12:47 - Adiran: Pero bro 555M es mucho dinero
# +++31/1/21 12:48 - Calleja: 555 de un total de 3600 no es desproporcionado
# +++31/1/21 12:48 - Calleja: Sobraba solo este año
# +++31/1/21 12:48 - Calleja: Que se habrian ahorrado 200 m con sueldo mas venta
# +++31/1/21 12:48 - Adiran: No se, hay que tener mas capacidad a la hora de hacer un trato
# +++31/1/21 12:49 - Calleja: Hay que medir la proporcion
# +++31/1/21 12:49 - Adiran: Como bartomeu no sirve para nada le convencio con dinero
# +++31/1/21 12:49 - Calleja: Tanto aspas como el cholo se les puede pagar esos porcentajes
# +++31/1/21 12:50 - Calleja: Sinceramente creo que tiene sentido sino pregunta cual es la proporcion en nba tambien por ejemplo
# +++31/1/21 12:50 - Calleja: Es lo que generes
# +++31/1/21 12:51 - Adiran: Pues entonces un porcentaje tendria que ser variable en funcion de champions etc
# +++31/1/21 12:51 - Adiran: Porque ganando eso tienes que llegar a semis siempre
# +++31/1/21 12:51 - Adiran: Digo el barsa
# +++31/1/21 12:51 - Calleja: Pero si messi te lleva siempre
# +++31/1/21 12:52 - Calleja: No se si te acuerdas del liverpool
# +++31/1/21 12:52 - Calleja: El problema no ha sido messi
# +++31/1/21 12:52 - Calleja: El problema son griezmann, untiti, dembele, coutinho, setien...
# +++31/1/21 12:53 - Wilf: Grande Griezmann
# +++31/1/21 12:57 - Adiran: Obviamente
# +++31/1/21 12:57 - Calleja: Si
# +++31/1/21 12:57 - Adiran: El unico que jugo ese partido
# +++31/1/21 13:23 - Wilf: Ojala algun dia en Europa establezcan algun limite presupuestario
# +++31/1/21 13:24 - Wilf: No tiene sentido que un jugador gane mas que el presupuesto del 80% de primera division😂
# +++31/1/21 13:24 - Wilf: Desvirtua la competicion
# +++31/1/21 13:24 - Wilf: Eso es algo que los estadounidenses lo hacen de puta madre
# +++31/1/21 13:24 - Wilf: Tienen 4 ligas que sus jugadores cobran millonadas
# +++31/1/21 13:25 - Wilf: Y dentro de nada 5 ligas, pq la MLS empieza a pagar bien
# +++31/1/21 13:25 - Wilf: 5 deportes millonarios
# +++31/1/21 13:25 - Calleja: Pero eso es otra cosa
# +++31/1/21 13:25 - Wilf: En España futbol y la ACB si juegas en el top
# +++31/1/21 13:25 - Wilf: Sino nah
# +++31/1/21 13:25 - Wilf: No tiene sentido ser del Valladolid o del Cadiz
# +++31/1/21 13:26 - Wilf: La F1 es igual hasta hace nada
# +++31/1/21 13:26 - Wilf: Ahora la han comprado Liberty Media (USA)
# +++31/1/21 13:26 - Wilf: Y van a poner un limite presupuestario
# +++31/1/21 13:26 - Wilf: Ojala cambie las cosas
# +++31/1/21 13:26 - Wilf: Pq esta siendo un puto coñazo, ganan los mismos
# +++31/1/21 13:27 - Wilf: Sisi si lo se
# +++31/1/21 13:27 - Wilf: Pero yo aqui digo lo que pienso xd
# +++31/1/21 13:27 - Wilf: Que lo genera Messi? Seguro
# +++31/1/21 13:28 - Wilf: Que no tiene sentido jugar la liga Santander con un jugador asi? Pues claro que no
# +++31/1/21 13:28 - Calleja: Es tema de filosofia
# +++31/1/21 13:28 - Calleja: En españa seria falsear
# +++31/1/21 13:29 - Calleja: Porque no hay ese presupuesto para mantener una liga equitativa
# +++31/1/21 13:29 - Calleja: Ya no se puede
# +++31/1/21 13:29 - Wilf: Ya , hay mucha tradicion
# +++31/1/21 13:29 - Wilf: Pero claro que se podria hacer
# +++31/1/21 13:29 - Wilf: Otra cosa es que no interese
# +++31/1/21 13:29 - Wilf: Basicamente pq hay Champions
# +++31/1/21 13:29 - Wilf: Y dudo que todas las ligas se pusieran de acuerdo
# +++31/1/21 13:53 - Ander: A mí me parece bien, que el 45% es de todos😂😂😂😂😂😂😂😂
# +++31/1/21 14:02 - Wilf: 😂
# +++31/1/21 14:06 - Adiran: Jajajajajjaja
# +++1/2/21 9:09 - Deivid: Chavales os acordáis de como se llama la pagina donde pillabamos camis de fútbol m
# +++1/2/21 9:09 - Deivid: ?
# +++1/2/21 10:44 - Wilf: www.youjizz.com
# +++1/2/21 10:46 - Deivid: Para la paja de hoy?
# +++1/2/21 10:46 - Deivid: De looocoooos
# +++1/2/21 10:49 - Deivid: Ostias si buscas en trending abajo del todo, en la bandera de españa pone sri lanka
# +++1/2/21 10:58 - Wilf: 😂😂😂 en que cosas te fijas😂😂😂
# +++1/2/21 15:22 - Deivid: El resto se acuerda? Que wilf es un payaso
# +++1/2/21 15:29 - Calleja: No
# +++1/2/21 15:41 - Gonzalo Manager: Noo
# +++1/2/21 15:41 - Gonzalo Manager: Pero si te molan clasicas y eso
# +++1/2/21 15:41 - Gonzalo Manager: Utiliza esta que siempre tiene cosas en ofertas y mola mucho
# +++1/2/21 15:42 - Gonzalo Manager: https://www.classicfootballshirts.co.uk
# +++1/2/21 15:45 - Deivid: Gracias man
# +++1/2/21 15:45 - Nano: De ahí sacaste la del Napoles eh, perro
# +++1/2/21 15:57 - Gonzalo Manager: Jejejeje
# +++1/2/21 16:31 - Tom: Chavales que algunos ya lo sabéis pero que lo sepáis todos, que lo he dejado con Mireia este último mes por muchas razones y nada, eso
# +++1/2/21 16:32 - Tom: Estoy bien y todo de forma muy amistosa y perfecto
# +++1/2/21 16:50 - Deivid: Bueno Tomas, si eso es lo mejor para ti, animo crack💪🏼. Me alegro que haya sido de buenas maneras
# +++1/2/21 17:02 - Ander: Ánimo bro, lo has importante es que haya sido amistoso y dentro de lo que cabe estés bien, mucho ánimo broder💪💪
# +++1/2/21 22:57 - Wilf: <Multimedia omitido>
# +++1/2/21 22:58 - Wilf: No se quien es la candidata catalana que suelta un NO😂
# +++1/2/21 22:58 - Wilf: En realidad es lamentable
# +++1/2/21 22:59 - Wilf: Como todos se callan y no tratan los temas importantes
# +++1/2/21 23:44 - Adiran: Tampoco yo se cual es la actualidad catalana
# +++1/2/21 23:44 - Adiran: Pero antes de la islamizacion diria 10000 cosas mas
# +++1/2/21 23:45 - Adiran: Pero si es una mofada jajaja
# +++2/2/21 0:12 - Wilf: Hace un par de meses se propuso y creo que se aprobo la implantacion de clases de islam en los coles😂
# +++2/2/21 0:12 - Wilf: No tiene mucho sentido, en gerenal quieren quitar religion de todos los sitios
# +++2/2/21 0:12 - Wilf: Religion catoliga no, el islam quiza xd
# +++2/2/21 9:15 - Adiran: Hombre espero que sea en todo caso de tipo voluntario
# +++2/2/21 9:33 - Adiran: Pero sino es pra meterles en la carcel a todos
# +++2/2/21 9:33 - Adiran: Que no se me habia mandado
# +++3/2/21 16:16 - Wilf: <Multimedia omitido>
# +++3/2/21 16:17 - Wilf: Mofas, yo sabia que hoy habia entrevista
# +++3/2/21 16:17 - Wilf: Y me he comido una hora viendo la tele y solo le han dejado hablar 5 mins😂
# +++3/2/21 16:17 - Wilf: Eso si, 10 mins hablando de laposible ruptura de Casillas y Sara, de canas y de mierdas
# +++3/2/21 16:17 - Wilf: Pero la entrevista lo que menos😂
# +++3/2/21 16:17 - Wilf: Lamentable la tele
# +++3/2/21 16:29 - Deivid: Puto Roma eh como las sielta
# +++3/2/21 16:32 - Wilf: Jajaja sin filtro
# Done. You can run next cell.

# %%
a_list = '🤔 🙈 me así, bla es se 😌 ds 💕👭👙'
re.findall(r'[^\w\s,]', a_list)
# Out:
# ['🤔', '🙈', '😌', '💕', '👭', '👙']

# %%
"""
DataFrame
"""
chat_per_member = (pd.DataFrame(member_chat)
                     .groupby(["member"])
                     .sum()
                     .sort_values(by = ['chat_count'], ascending=False))
popular_words_df = sorted(popular_words.items(), key=operator.itemgetter(1), reverse=True)
domains = (pd.DataFrame(refered_web)
                     .groupby(["domain"])
                     .sum()
                     .sort_values(by = ['d_count'], ascending=False))
emojis_df = (pd.DataFrame(emojis)
                     .groupby(["emj_char"])
                     .sum()
                     .sort_values(by = ['char_count'], ascending=False))
top_repeated_emoji = (pd.DataFrame(emojis)
                     .sort_values(by = ['char_count'], ascending=False))
heatmap_df = pd.DataFrame(heat_map)
grouped_heatmap = heatmap_df.groupby(["day", "hour"]).sum().sort_values(by=["chat_count"], ascending=False)
pivoted_heatmap = pd.pivot_table(grouped_heatmap, values='chat_count', index=['day'], columns=['hour'])

print("Done. You can run next cell.")
# Out:
# Done. You can run next cell.

# %%
for key in member_words.keys():
    words_list = member_words[key]
    a = " ".join(words_list)
    member_words[key] = a

member_words_df = pd.DataFrame([[key, member_words[key]] for key in member_words.keys()], columns=['User', 'Words'])
member_words_df.index = member_words_df.User
member_words_df
# Out:
#                     User                                              Words
# User
# Girls club   Girls club   mensajes llamadas estn cifrados extremo extrem...
# Sofia LM        Sofia LM  chicaas estaiis nica salimos tres jjaaja verge...
# María S.        María S.  sofiii tal bieeen curro bueno ayuda pasen rpid...
# Aroa LM          Aroa LM  sofa llev marca encontr izquierda suena finde ...
# Isa LM            Isa LM  chicaaaaaaaaaas bon diaaaaaaq chachi grupo jej...

# %%
# !pip install textblob
# !pip install wordcloud
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.6/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.6/dist-packages (from textblob) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk>=3.1->textblob) (1.15.0)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from wordcloud) (7.0.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from wordcloud) (1.19.5)

# %%
from textblob import TextBlob
    
pol = lambda x: TextBlob(x).sentiment.polarity
pol2 = lambda x: x.sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity
sub2 = lambda x: x.sentiment.subjectivity
 
traducir = lambda x: TextBlob(x).translate(to="en")
 
member_words_df['blob_en'] = member_words_df['Words'].apply(traducir)
member_words_df['polarity'] = member_words_df['blob_en'].apply(pol2)
member_words_df['subjectivity'] = member_words_df['blob_en'].apply(sub2)
member_words_df = member_words_df.drop('Girls club ')
member_words_df.index
# Out:
# Index(['Sofia LM', 'María S.', 'Aroa LM', 'Isa LM'], dtype='object', name='User')

# %%
plt.rcParams['figure.figsize'] = [10, 8]
 
for index, user in enumerate(member_words_df.index):
    x = member_words_df.polarity.loc[user]
    y = member_words_df.subjectivity.loc[user]
    plt.scatter(x, y, color='red')
    plt.text(x+.001, y+.001, member_words_df['User'][user], fontsize=10)
    plt.xlim(-0.051, 0.3) 
    
plt.title('Sentiment Analysis', fontsize=20)
plt.xlabel('<-- Negative -------- Positive -->', fontsize=15)
plt.ylabel('<-- Facts -------- Opinions -->', fontsize=15)
 
plt.show()

# %%
from wordcloud import WordCloud
 
wc = WordCloud(background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)
 
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16,12]
 
# Create subplots for each anio
for index, user in enumerate(member_words_df.index):
    wc.generate(member_words_df.Words[user])
    plt.subplot(4, 3, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(user)
plt.show()

# %%
chat_per_member = chat_per_member.drop('Girls club ')

# %%
"""
Top Member Chat
"""
top_member = chat_per_member.head(20)
if not top_member.empty:
    sns.set()
    member_plot = top_member.plot(kind='bar', legend=None, title="Top 20 active member", figsize=(18, 6), color="purple")
    member_plot.set_xlabel("Member (phone number/contact name)")
    member_plot.set_ylabel("Chat Count")
    for i, v in enumerate(top_member["chat_count"]):
        member_plot.text(i - .15, v + 3, v, color="#004d40")
else:
    print("This chat has no member")

# %%
"""
Heatmap
"""
heatmap_df = pd.DataFrame(heat_map)
if not heatmap_df.empty:
    grouped_heatmap = heatmap_df.groupby(["day", "hour"]).sum().sort_values(by=["chat_count"], ascending=False)
    pivoted_heatmap = pd.pivot_table(grouped_heatmap, values='chat_count', index=['day'], columns=['hour'])
    plt.figure(figsize = (16,5))
    sns.heatmap(pivoted_heatmap, 
                annot=True, 
                fmt=".0f", 
                linewidths=.2,
                cmap="YlGnBu",
                cbar=False
               )
else:
    print("This chat does not contain any datetime")

# %%
s_attachments = sorted(attachments.items(), key = operator.itemgetter(1), reverse=True)
if s_attachments:
    at_labels = [x[0].title() + " " + str(x[1]) for x in s_attachments]

    at_explode = tuple([0 + i * 0.1 for i in range(len(s_attachments))])
    at_sizes = [x[1] for x in s_attachments]
    at_colors = ["#FF6D00", "#64DD17", "#00B8D4", "#304FFE", "#AA00FF", "#d50000", "#546E7A", "#dddddd"]
    at_pie = plt.pie(at_sizes,  
             autopct='%1.1f%%',
             explode=at_explode,
             pctdistance=1.2,
             colors=at_colors,
             startangle=160,
             radius=1.3,
             wedgeprops = { 'linewidth' : 2, 'edgecolor' : 'white' },
    )

    at_centre_circle = plt.Circle((0,0),0.85,color='white', fc='white',linewidth=1.25)
    at_fig = plt.gcf()
    at_fig.gca().add_artist(at_centre_circle)

    plt.legend(
        loc='upper left',
        labels=at_labels,
        prop={'size': 11},
        bbox_to_anchor=(1, 1)
    )
    at_axis = plt.axis('equal')
else:
    print("This chat contains no attachment.")
# Out:
# This chat contains no attachment.

# %%
"""
Top Website
"""
top_web = domains.head(20).sort_values("d_count")
if not top_web.empty:
    mpl.rc('font', **{'sans-serif' : 'arial', 'family' : 'sans-serif'})
    web_plot = top_web.plot(kind='barh', legend=None, title="Top 20 mentioned domain", figsize=(20,10), color="#1de9b6")
    web_plot.set_xlabel("Mention Count")
    for i, v in enumerate(top_web["d_count"]):
        web_plot.text(1, i - .15, v, color="purple")
else:
    print("This chat not contains any link")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
"""
Wordcloud
"""
if chat_words:
    wordcloud = WordCloud(
        width = 1000, 
        height = 500,
        background_color = "white"
    ).generate(chat_words)

    plt.figure(figsize=(15,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
else:
    print("This chat contains no word")

# %%
"""
Raw Output
"""
print("\n=======================================\n")
print("#Total Chat: {0}".format(total_chat))
print("#Deleted Message: {0}".format(deleted_message))
print("#Total Attachment: {0}".format(sum([x[1] for x in s_attachments])))
for a in s_attachments:
    print("  - : {0}".format(a))
    


print("\n#Top 20 Member")
print("-----------------")
print(top_member)


print("\n#Top 20 Words")
print("-----------------")
for k, v in enumerate(popular_words_df):
    if k < 20:
        print(v)
    else:
        break
        
print("\n#Top 20 Emoji")
print("-----------------")
print(emojis_df.head(20))

print("\n#Top 20 Mentioned Website")
print("-----------------")
print(top_web.sort_values("d_count", ascending=False))
# Out:
# =======================================
#
# #Total Chat: 1668
# #Deleted Message: 0
# #Total Attachment: 0
#
# #Top 20 Member
# -----------------
#           chat_count
# member
# Sofia LM         638
# Isa LM           392
# María S.         381
# Aroa LM          256
#
# #Top 20 Words
# -----------------
# ('chicas', 43)
# ('ver', 38)
# ('tengo', 37)
# ('jaja', 30)
# ('ms', 30)
# ('bueno', 28)
# ('voy', 27)
# ('genial', 26)
# ('igual', 24)
# ('jajaja', 23)
# ('tambin', 22)
# ('puedo', 21)
# ('finde', 21)
# ('tal', 20)
# ('semana', 20)
# ('vamos', 20)
# ('sitio', 20)
# ('sii', 19)
# ('guay', 18)
# ('queris', 18)
#
# #Top 20 Emoji
# -----------------
# Empty DataFrame
# Columns: [char_count]
# Index: []
#
# #Top 20 Mentioned Website
# -----------------
#                         d_count
# domain
# goo.gl                        5
# maps.app.goo.gl               4
# instagram.com                 2
# www.elmundo.es                2
# www.gruposaona.com            2
# elpais.com                    1
# g.co                          1
# livingmeki.org                1
# madriddiferente.com           1
# www.elperiodico.com           1
# www.instagram.com             1
# www.modemovimiento.com        1
# www.opentable.es              1
# www.tripadvisor.es            1
# youtu.be                      1

# %% [markdown]
# **Análisis de sentimientos**

# %%
emojis_df
# Out:
# Empty DataFrame
# Columns: [char_count]
# Index: []
